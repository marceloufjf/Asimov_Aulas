# %% [markdown]
# <a href="https://colab.research.google.com/github/marceloufjf/Asimov_Aulas/blob/main/Asimov_Curso_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Análise de dados - Portal da Transparência**

# %%
caminho_dados = "/content/drive/MyDrive/ASIMOV ACADEMY/PYTHON_PARA_DADOS/Conteúdo feito em aula/2023_Viagem.csv"

# %%
import pandas as pd

pd.set_option('display.max_columns', None) # O "None" é pra indicar que não limitarei valor máximo para colunas.
pd.set_option('display.float_format', '{:.2f}'.format)

# Lendo os dados:
df_dados = pd.read_csv(caminho_dados, encoding="Windows-1252", sep=";")

# Formatando os valores das despesas de string para float. Desta foram permitem que sejam somados.
df_dados["Valor diárias"] = df_dados["Valor diárias"].str.replace(",", ".").astype(float)
df_dados["Valor passagens"] = df_dados["Valor passagens"].str.replace(",", ".").astype(float)
df_dados["Valor devolução"] = df_dados["Valor devolução"].str.replace(",", ".").astype(float)
df_dados["Valor outros gastos"] = df_dados["Valor outros gastos"].str.replace(",", ".").astype(float)

# Criando nova coluna de despesas:
df_dados["Despesas totais"] = df_dados["Valor diárias"] + df_dados["Valor passagens"] + df_dados["Valor outros gastos"]

# Ajustando os valores nulos na coluna de cargo:
df_dados["Cargos"] = df_dados["Cargo"].fillna("Não informado") # A coluna "Cargos" foi criada sem querer:
df_dados["Cargo"] = df_dados["Cargo"].fillna("Não informado")

# Formatando coluna de datas:
df_dados["Período - Data de início"] = pd.to_datetime(df_dados["Período - Data de início"], format = "%d/%m/%Y")
df_dados["Período - Data de fim"] = pd.to_datetime(df_dados["Período - Data de fim"], format = "%d/%m/%Y")

# Criando novas colunas de datas:
df_dados["Mês da viagem"] = df_dados["Período - Data de início"].dt.month_name()
df_dados["Dias de viagem"] = (df_dados["Período - Data de fim"] - df_dados["Período - Data de início"]).dt.days

# %%
# Criacão da Tabela consolidada:

df_dados_consolidado = (
    df_dados
    .groupby("Cargo")
    .agg(
        Despesa_media=("Despesas totais", "mean"),
        Dias_de_viagem_medio=("Dias de viagem", "mean"),
        Despesas_soma=("Despesas totais", "sum"),
        Destinos_mais_frequentes=("Destinos", pd.Series.mode),
        Numero_de_viagens=("Destinos", "count")
        )
    .reset_index()
    .sort_values(by="Despesa_media",ascending=False)
    )

# Filtrando tabela consolidada por cargos relevantes (> 1% das viagens):

df_cargos = df_dados["Cargo"].value_counts(normalize=True).reset_index()
cargos_relevantes = df_cargos.loc[df_cargos["proportion"] > 0.01, "Cargo"]
filtro = df_dados_consolidado["Cargo"].isin(cargos_relevantes)

# Chegando na tabela final - Filtrada e consolidade:

df_final = df_dados_consolidado[filtro].sort_values(by="Despesa_media",ascending=False)

# %%
df_final
# Out:
#                                         Cargo  Despesa_media  \
# 686                  TECNICO DO SEGURO SOCIAL        4302.48
# 494                             Não informado        3260.26
# 443         Informações protegidas por sigilo        3137.48
# 72                         ANALISTA AMBIENTAL        2596.94
# 209  AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL        2418.11
# 569          PROFESSOR DO MAGISTERIO SUPERIOR        2032.08
# 113    ANALISTA TRIBUTARIO REC FEDERAL BRASIL        1746.79
# 208       AUDITOR FISCAL FEDERAL AGROPECUARIO        1465.85
# 776   TECNICO INFOR GEOGRAFICAS E ESTATISTICA        1457.08
# 570     PROFESSOR ENS BASICO TECN TECNOLOGICO        1402.20
# 179               ASSISTENTE EM ADMINISTRAçãO        1291.03
# 315               CONTRATADO LEI 8745/93 - NI         984.45
#
#      Dias_de_viagem_medio  Despesas_soma           Destinos_mais_frequentes  \
# 686                 11.37    45881679.92                        Brasília/DF
# 494                  8.01  1049266194.86                        Brasília/DF
# 443                  7.41   370919369.30  Informações protegidas por sigilo
# 72                   5.13    35344371.79                        Brasília/DF
# 209                  2.84    24405946.47                        Brasília/DF
# 569                  3.87   110890764.22                        Brasília/DF
# 113                  3.06    14868670.22                   Foz do Iguaçu/PR
# 208                  2.06    24306782.30                        Brasília/DF
# 776                  3.19    15816641.46                        Brasília/DF
# 570                  2.34    52548741.25                        Brasília/DF
# 179                  2.17    15094703.63                        Brasília/DF
# 315                  2.84    17510463.07                           Bauru/SP
#
#      Numero_de_viagens
# 686              10664
# 494             321835
# 443             118222
# 72               13610
# 209              10093
# 569              54570
# 113               8512
# 208              16582
# 776              10855
# 570              37476
# 179              11692
# 315              17787

# %%
# GRÁFICO

import matplotlib.pyplot as plt


df_final = df_final.sort_values(by="Numero_de_viagens",ascending=False)

# Criando a figura
fig, ax = plt.subplots(figsize=(16, 6))

# Plotando o gráfico
ax.barh(df_final["Cargo"], df_final["Numero_de_viagens"], color = "#3ee679")
ax.invert_yaxis()

# Ajustando o gráfico
ax.set_facecolor("#1c273b")
fig.suptitle("Viagens por cargo público (2023)")
plt.figtext(0.89, 0.90, "Fonte: Portal da Transparência", fontsize=10, ha="right")
plt.grid(color = "gray", linestyle = "--", linewidth = "0.2")
plt.yticks(fontsize = 8)
plt.xlabel("Número de viagens")

# Exibindo o gráfico
plt.show()

# %%
df_dados
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18236583                 000018/23
# 2                                  18288418              000007/23-1C
# 3                                  18296348                 000070/23
# 4                                  18302983                 000001/23
# ...                                     ...                       ...
# 826984                           2023001618             Sem informaçã
# 826985                           2023001619             Sem informaçã
# 826986                           2023001628             Sem informaçã
# 826987                           2023001631             Sem informaçã
# 826988                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# 2       Realizada            SIM
# 3       Realizada            SIM
# 4       Realizada            NÃO
# ...           ...            ...
# 826984  Realizada            NÃO
# 826985  Realizada            NÃO
# 826986  Realizada            NÃO
# 826987  Realizada            NÃO
# 826988  Realizada            NÃO
#
#                             Justificativa Urgência Viagem  \
# 0                                          Sem informação
# 1                                          Sem informação
# 2                             Por necessidade do serviço.
# 3       A efetivação do empenho no Siafi e a respectiv...
# 4                                          Sem informação
# ...                                                   ...
# 826984                                     Sem informação
# 826985                                     Sem informação
# 826986                                     Sem informação
# 826987                                     Sem informação
# 826988                                     Sem informação
#
#         Código do órgão superior  Nome do órgão superior  \
# 0                          26000  Ministério da Educação
# 1                          26000  Ministério da Educação
# 2                          52000    Ministério da Defesa
# 3                          26000  Ministério da Educação
# 4                          52000    Ministério da Defesa
# ...                          ...                     ...
# 826984                        -1          Sem informação
# 826985                        -1          Sem informação
# 826986                        -1          Sem informação
# 826987                        -1          Sem informação
# 826988                        -1          Sem informação
#
#         Código órgão solicitante                Nome órgão solicitante  \
# 0                          26352  Fundação Universidade Federal do ABC
# 1                          26236       Universidade Federal Fluminense
# 2                          52121                   Comando do Exército
# 3                          26406   Instituto Federal do Espírito Santo
# 4                          52111                Comando da Aeronáutica
# ...                          ...                                   ...
# 826984                        -1                        Sem informação
# 826985                        -1                        Sem informação
# 826986                        -1                        Sem informação
# 826987                        -1                        Sem informação
# 826988                        -1                        Sem informação
#
#           CPF viajante                             Nome  \
# 0       ***.875.238-**           PRISCILA LEAL DA SILVA
# 1                  NaN          CAMILLA DUARTE DA SILVA
# 2       ***.621.358-**     ANDRE LUIS COSTA PITANGUEIRA
# 3       ***.407.547-**     LIDIANY MIRANDA FERRAZ NUNES
# 4       ***.855.388-**                    GREGOR GASPAR
# ...                ...                              ...
# 826984  ***.748.269-**               BIANCA VIANA KIVEL
# 826985  ***.231.806-**               LUCAS ALVES FREIRE
# 826986  ***.632.011-**                   SERGIO BOTELHO
# 826987  ***.407.445-**        NELSON CAMPOS REIS JUNIOR
# 826988  ***.602.017-**  ROBERTO DE OLIVEIRA CAMPOS NETO
#
#                                    Cargo      Função Descrição Função  \
# 0       PROFESSOR DO MAGISTERIO SUPERIOR          -1   Sem informação
# 1           BIBLIOTECARIO-DOCUMENTALISTA          -1   Sem informação
# 2                          Não informado  OfSuperior       OfSuperior
# 3                AUXILIAR DE BIBLIIOTECA          -1   Sem informação
# 4                          Não informado  OfIntermed       OfIntermed
# ...                                  ...         ...              ...
# 826984         ANALISTA DO BANCO CENTRAL          -1   Sem informação
# 826985       PROCURADOR DO BANCO CENTRAL          -1   Sem informação
# 826986          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826987          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826988       PRESIDENTE DO BANCO CENTRAL          -1   Sem informação
#
#        Período - Data de início Período - Data de fim  \
# 0                    2023-01-01            2023-12-02
# 1                    2023-01-16            2024-02-28
# 2                    2023-01-10            2023-01-29
# 3                    2023-02-05            2023-02-10
# 4                    2023-01-01            2023-07-07
# ...                         ...                   ...
# 826984               2023-12-05            2023-12-06
# 826985               2023-12-11            2023-12-13
# 826986               2023-12-07            2023-12-08
# 826987               2023-12-11            2023-12-11
# 826988               2023-12-15            2023-12-18
#
#                                    Destinos  \
# 0                  Loughborough/Reino Unido
# 1                         Rio de Janeiro/RJ
# 2       Nova York/Estados Unidos da América
# 3                                Vitória/ES
# 4                         Gotemburgo/Suécia
# ...                                     ...
# 826984                       Sem informação
# 826985                       Sem informação
# 826986                       Sem informação
# 826987                       Sem informação
# 826988                       Sem informação
#
#                                                    Motivo  Valor diárias  \
# 0            Intercâmbio acadêmico PCDP anterior 07/21-3C           0.00
# 1       Afastamento para pós-graduação stricto sensu n...           0.00
# 2       Participar da revisão do COE Manual (Contingen...       39565.70
# 3       Participação das aulas de Mestrado Interinstit...        1013.96
# 4            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# ...                                                   ...            ...
# 826984  Participar de tratativas nos locais das reuniõ...         606.89
# 826985                   Participar da reunião do COPOM .        1089.00
# 826986     Acompanhamento do Presidente do BC - São Paulo         734.13
# 826987          Acompanhamento do Presidente - São Paulo.         319.28
# 826988                       Cumprir agenda em São Paulo.           0.00
#
#         Valor passagens  Valor devolução  Valor outros gastos  \
# 0                  0.00             0.00                 0.00
# 1                  0.00             0.00                 0.00
# 2               7434.13             0.00              1095.35
# 3                  0.00             0.00                 0.00
# 4              14903.10             0.00                 0.00
# ...                 ...              ...                  ...
# 826984          3331.29             0.00                 0.00
# 826985          1837.18             0.00                 0.00
# 826986          4555.95             0.00                 0.00
# 826987          3745.53             0.00               400.00
# 826988          2961.55             0.00                 0.00
#
#         Despesas totais                            Cargos Mês da viagem  \
# 0                  0.00  PROFESSOR DO MAGISTERIO SUPERIOR       January
# 1                  0.00      BIBLIOTECARIO-DOCUMENTALISTA       January
# 2              48095.18                     Não informado       January
# 3               1013.96           AUXILIAR DE BIBLIIOTECA      February
# 4              14903.10                     Não informado       January
# ...                 ...                               ...           ...
# 826984          3938.18         ANALISTA DO BANCO CENTRAL      December
# 826985          2926.18       PROCURADOR DO BANCO CENTRAL      December
# 826986          5290.08          TECNICO DO BANCO CENTRAL      December
# 826987          4464.81          TECNICO DO BANCO CENTRAL      December
# 826988          2961.55       PRESIDENTE DO BANCO CENTRAL      December
#
#         Dias de viagem
# 0                  335
# 1                  408
# 2                   19
# 3                    5
# 4                  187
# ...                ...
# 826984               1
# 826985               2
# 826986               1
# 826987               0
# 826988               3
#
# [826989 rows x 26 columns]

# %%
# Análise da relação da despesas com os dias de viagem.

fig, ax = plt.subplots(figsize=(16, 6))

ax.scatter(df_dados["Dias de viagem"], df_dados["Despesas totais"], alpha=0.1)
# ax.set_xlim(0, 100)    Argumentos para limitar o eixo x, y e desta forma aumentar o zoom_
# ax.set_ylim(0, 25_000) _do gráfico.

# %%
# Filtro com os maiores valores.

(df_dados['Despesas totais'] > 175_000).value_counts()
# Out:
# Despesas totais
# False    826985
# True          4
# Name: count, dtype: int64

# %%
filtro = df_dados['Despesas totais'] > 175_000
df_dados[filtro]
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 129008                             18782567              000277/23-5C
# 129058                             18782625              000289/23-5C
# 206998                             18877982             Informações p
# 466711                             19194886                 004304/23
#
#          Situação Viagem Urgente  \
# 129008  Realizada            SIM
# 129058  Realizada            SIM
# 206998  Realizada            NÃO
# 466711  Realizada            SIM
#
#                             Justificativa Urgência Viagem  \
# 129008  A autorização de afastamento foi publicada hoj...
# 129058  Devido ao cancelamento da Visita Oficial do PR...
# 206998  Informação protegida por sigilo nos termos da ...
# 466711  Mudança de itinerário devido à situação na Fai...
#
#         Código do órgão superior                     Nome do órgão superior  \
# 129008                     20000                   Presidência da República
# 129058                     20000                   Presidência da República
# 206998                     30000  Ministério da Justiça e Segurança Pública
# 466711                     35000         Ministério das Relações Exteriores
#
#         Código órgão solicitante  \
# 129008                     20000
# 129058                     20000
# 206998                     30108
# 466711                     35000
#
#                                    Nome órgão solicitante    CPF viajante  \
# 129008  Presidência da República - Unidades com víncul...  ***.739.980-**
# 129058  Presidência da República - Unidades com víncul...  ***.919.570-**
# 206998                                    Polícia Federal     ID006200249
# 466711  Ministério das Relações Exteriores - Unidades ...  ***.501.297-**
#
#                                      Nome                              Cargo  \
# 129008           LEANDRO AUGUSTO ANDERSON                      Não informado
# 129058       LUIS CARLOS MACHADO DA SILVA                      Não informado
# 206998  Informações protegidas por sigilo  Informações protegidas por sigilo
# 466711           MAURO LUIZ IECKER VIEIRA        MINISTRO DE PRIMEIRA CLASSE
#
#           Função                   Descrição Função Período - Data de início  \
# 129008  CCX-0207                           CCX-0207               2023-03-26
# 129058  CCX-0207                           CCX-0207               2023-03-26
# 206998       -11  Informações protegidas por sigilo               2023-06-18
# 466711  CNE-0001         Cargo de Natureza Especial               2023-10-06
#
#        Período - Data de fim  \
# 129008            2023-08-04
# 129058            2023-08-06
# 206998            2024-01-20
# 466711            2023-10-15
#
#                                                  Destinos  \
# 129008                         Xangai/China, São Paulo/SP
# 129058                         Xangai/China, São Paulo/SP
# 206998                  Informações protegidas por sigilo
# 466711  Jacarta/Indonésia, Phnom Penh/Camboja, Nova Yo...
#
#                                                    Motivo  Valor diárias  \
# 129008  Conforme o previsto no Decreto nº 6.381 de 27 ...      174812.69
# 129058  Conforme o previsto no Decreto nº 6.381 de 27 ...      175337.40
# 206998  Informação protegida por sigilo nos termos da ...      160692.47
# 466711     Visitas oficiais a países do Sudeste Asiático.        8468.86
#
#         Valor passagens  Valor devolução  Valor outros gastos  \
# 129008         11610.06             0.00              5625.81
# 129058         11757.14             0.00              5581.48
# 206998         14583.60             0.00              9511.35
# 466711        186723.29             0.00                 0.00
#
#         Despesas totais                             Cargos Mês da viagem  \
# 129008        192048.56                      Não informado         March
# 129058        192676.02                      Não informado         March
# 206998        184787.42  Informações protegidas por sigilo          June
# 466711        195192.15        MINISTRO DE PRIMEIRA CLASSE       October
#
#         Dias de viagem
# 129008             131
# 129058             133
# 206998             216
# 466711               9

# %% [markdown]
# ##**Filtro com as passagens mais caras:**

# %%
# Importação de dados de passagens:

caminho_passagens = "/content/drive/MyDrive/ASIMOV ACADEMY/PYTHON_PARA_DADOS/Conteúdo feito em aula/2023_Passagem.csv"

# %%
df_passagens = pd.read_csv(caminho_passagens, encoding="Windows-1252", sep=";")

# %%
df_passagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  18288418              000007/23-1C
# 1                                  18302983                 000001/23
# 2                                  18306758                 000002/23
# 3                                  18306785                 000004/23
# 4                                  18306786                 000003/23
# ...                                     ...                       ...
# 387668                           2023001628             Sem informaçã
# 387669                           2023001628             Sem informaçã
# 387670                           2023001631             Sem informaçã
# 387671                           2023001631             Sem informaçã
# 387672                           2023001651             Sem informaçã
#
#        Meio de transporte País - Origem ida   UF - Origem ida  \
# 0                   Aéreo            Brasil  Distrito Federal
# 1                   Aéreo            Brasil         São Paulo
# 2                   Aéreo            Brasil         São Paulo
# 3                   Aéreo            Brasil         São Paulo
# 4                   Aéreo            Brasil         São Paulo
# ...                   ...               ...               ...
# 387668              Aéreo            Brasil  Distrito Federal
# 387669              Aéreo            Brasil         São Paulo
# 387670              Aéreo            Brasil  Distrito Federal
# 387671              Aéreo            Brasil         São Paulo
# 387672              Aéreo            Brasil  Distrito Federal
#
#        Cidade - Origem ida         País - Destino ida  UF - Destino ida  \
# 0                 Brasília  Estados Unidos da América               NaN
# 1                São Paulo                     Suécia               NaN
# 2                São Paulo                     Suécia               NaN
# 3                São Paulo                     Suécia               NaN
# 4                São Paulo                     Suécia               NaN
# ...                    ...                        ...               ...
# 387668            Brasília                     Brasil         São Paulo
# 387669           São Paulo                     Brasil  Distrito Federal
# 387670            Brasília                     Brasil         São Paulo
# 387671           São Paulo                     Brasil  Distrito Federal
# 387672            Brasília                     Brasil         São Paulo
#
#        Cidade - Destino ida        País - Origem volta UF - Origem volta  \
# 0                 Nova York  Estados Unidos da América               NaN
# 1                Gotemburgo                     Suécia               NaN
# 2                Gotemburgo                     Suécia               NaN
# 3                Gotemburgo                     Suécia               NaN
# 4                Gotemburgo                     Suécia               NaN
# ...                     ...                        ...               ...
# 387668            São Paulo             Sem informação    Sem informação
# 387669             Brasília             Sem informação    Sem informação
# 387670            São Paulo             Sem informação    Sem informação
# 387671             Brasília             Sem informação    Sem informação
# 387672            São Paulo             Sem informação    Sem informação
#
#        Cidade - Origem volta Pais - Destino volta UF - Destino volta  \
# 0                  Nova York               Brasil   Distrito Federal
# 1                 Gotemburgo               Brasil          São Paulo
# 2                 Gotemburgo               Brasil          São Paulo
# 3                 Gotemburgo               Brasil          São Paulo
# 4                 Gotemburgo               Brasil          São Paulo
# ...                      ...                  ...                ...
# 387668        Sem informação       Sem informação     Sem informação
# 387669        Sem informação       Sem informação     Sem informação
# 387670        Sem informação       Sem informação     Sem informação
# 387671        Sem informação       Sem informação     Sem informação
# 387672        Sem informação       Sem informação     Sem informação
#
#        Cidade - Destino volta Valor da passagem Taxa de serviço  \
# 0                    Brasília           7434,13               0
# 1                   São Paulo           9903,32         4999,78
# 2                   São Paulo           9903,32         4999,78
# 3                   São Paulo           9903,32         4999,78
# 4                   São Paulo           9903,32         4999,78
# ...                       ...               ...             ...
# 387668         Sem informação           2791,41               0
# 387669         Sem informação           1764,54               0
# 387670         Sem informação           1985,65               0
# 387671         Sem informação           1759,88               0
# 387672         Sem informação           2961,55               0
#
#        Data da emissão/compra Hora da emissão/compra
# 0                  04/11/2022                  11:04
# 1                  15/09/2022                  13:39
# 2                  15/09/2022                  13:42
# 3                  15/09/2022                  13:51
# 4                  15/09/2022                  13:48
# ...                       ...                    ...
# 387668                    NaN                  00:00
# 387669                    NaN                  00:00
# 387670                    NaN                  00:00
# 387671                    NaN                  00:00
# 387672                    NaN                  00:00
#
# [387673 rows x 19 columns]

# %%
# Filtro com os maiores valores de passagens:

df_passagens[df_passagens["Identificador do processo de viagem"] == 19194886]
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 232069                             19194886                 004304/23
# 232070                             19194886                 004304/23
# 232071                             19194886                 004304/23
# 232072                             19194886                 004304/23
# 232073                             19194886                 004304/23
# 232074                             19194886                 004304/23
# 232075                             19194886                 004304/23
#
#        Meio de transporte          País - Origem ida UF - Origem ida  \
# 232069              Aéreo  Estados Unidos da América             NaN
# 232070              Aéreo                  Indonésia             NaN
# 232071              Aéreo  Estados Unidos da América             NaN
# 232072              Aéreo                  Cingapura             NaN
# 232073              Aéreo                  Filipinas             NaN
# 232074              Aéreo                     Brasil       São Paulo
# 232075              Aéreo                    Camboja             NaN
#
#             Cidade - Origem ida         País - Destino ida UF - Destino ida  \
# 232069                Nova York                     Brasil        São Paulo
# 232070                  Jacarta                    Camboja              NaN
# 232071                Nova York                     Brasil        São Paulo
# 232072                Cingapura  Estados Unidos da América              NaN
# 232073  San Juan - Metro Manila                     Brasil        São Paulo
# 232074                São Paulo                  Indonésia              NaN
# 232075               Phnom Penh                  Cingapura              NaN
#
#        Cidade - Destino ida País - Origem volta UF - Origem volta  \
# 232069            São Paulo      Sem informação    Sem informação
# 232070           Phnom Penh      Sem informação    Sem informação
# 232071            São Paulo      Sem informação    Sem informação
# 232072            Nova York      Sem informação    Sem informação
# 232073            São Paulo      Sem informação    Sem informação
# 232074              Jacarta      Sem informação    Sem informação
# 232075            Cingapura      Sem informação    Sem informação
#
#        Cidade - Origem volta Pais - Destino volta UF - Destino volta  \
# 232069        Sem informação       Sem informação     Sem informação
# 232070        Sem informação       Sem informação     Sem informação
# 232071        Sem informação       Sem informação     Sem informação
# 232072        Sem informação       Sem informação     Sem informação
# 232073        Sem informação       Sem informação     Sem informação
# 232074        Sem informação       Sem informação     Sem informação
# 232075        Sem informação       Sem informação     Sem informação
#
#        Cidade - Destino volta Valor da passagem Taxa de serviço  \
# 232069         Sem informação          35304,33               0
# 232070         Sem informação           1667,56               0
# 232071         Sem informação          51557,43               0
# 232072         Sem informação          42368,61               0
# 232073         Sem informação           7926,43               0
# 232074         Sem informação          41529,96               0
# 232075         Sem informação           6368,97               0
#
#        Data da emissão/compra Hora da emissão/compra
# 232069             20/11/2023                  17:47
# 232070             22/08/2023                  14:53
# 232071             17/10/2023                  17:58
# 232072             17/10/2023                  17:57
# 232073             20/09/2023                  11:06
# 232074             22/08/2023                  14:53
# 232075             17/10/2023                  16:33

# %%
df_dados.merge(df_passagens) # o "merge" é usado para cruzar dados de tabelas.
                             # o "merge" usa uma coluna comum das tabelas para cruzarem os dados.
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  18288418              000007/23-1C
# 1                                  18302983                 000001/23
# 2                                  18306758                 000002/23
# 3                                  18306785                 000004/23
# 4                                  18306786                 000003/23
# ...                                     ...                       ...
# 387676                           2023001628             Sem informaçã
# 387677                           2023001628             Sem informaçã
# 387678                           2023001631             Sem informaçã
# 387679                           2023001631             Sem informaçã
# 387680                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente Justificativa Urgência Viagem  \
# 0       Realizada            SIM   Por necessidade do serviço.
# 1       Realizada            NÃO                Sem informação
# 2       Realizada            NÃO                Sem informação
# 3       Realizada            NÃO                Sem informação
# 4       Realizada            NÃO                Sem informação
# ...           ...            ...                           ...
# 387676  Realizada            NÃO                Sem informação
# 387677  Realizada            NÃO                Sem informação
# 387678  Realizada            NÃO                Sem informação
# 387679  Realizada            NÃO                Sem informação
# 387680  Realizada            NÃO                Sem informação
#
#         Código do órgão superior Nome do órgão superior  \
# 0                          52000   Ministério da Defesa
# 1                          52000   Ministério da Defesa
# 2                          52000   Ministério da Defesa
# 3                          52000   Ministério da Defesa
# 4                          52000   Ministério da Defesa
# ...                          ...                    ...
# 387676                        -1         Sem informação
# 387677                        -1         Sem informação
# 387678                        -1         Sem informação
# 387679                        -1         Sem informação
# 387680                        -1         Sem informação
#
#         Código órgão solicitante  Nome órgão solicitante    CPF viajante  \
# 0                          52121     Comando do Exército  ***.621.358-**
# 1                          52111  Comando da Aeronáutica  ***.855.388-**
# 2                          52111  Comando da Aeronáutica  ***.295.391-**
# 3                          52111  Comando da Aeronáutica  ***.221.068-**
# 4                          52111  Comando da Aeronáutica  ***.850.918-**
# ...                          ...                     ...             ...
# 387676                        -1          Sem informação  ***.632.011-**
# 387677                        -1          Sem informação  ***.632.011-**
# 387678                        -1          Sem informação  ***.407.445-**
# 387679                        -1          Sem informação  ***.407.445-**
# 387680                        -1          Sem informação  ***.602.017-**
#
#                                    Nome                        Cargo  \
# 0          ANDRE LUIS COSTA PITANGUEIRA                Não informado
# 1                         GREGOR GASPAR                Não informado
# 2              VITOR LUIS MARTINS FARIA                Não informado
# 3       RAFAEL RODRIGO MANCIN DE MORAIS                Não informado
# 4          BRUNO NOCENTE REGATO PEREIRA                Não informado
# ...                                 ...                          ...
# 387676                   SERGIO BOTELHO     TECNICO DO BANCO CENTRAL
# 387677                   SERGIO BOTELHO     TECNICO DO BANCO CENTRAL
# 387678        NELSON CAMPOS REIS JUNIOR     TECNICO DO BANCO CENTRAL
# 387679        NELSON CAMPOS REIS JUNIOR     TECNICO DO BANCO CENTRAL
# 387680  ROBERTO DE OLIVEIRA CAMPOS NETO  PRESIDENTE DO BANCO CENTRAL
#
#             Função Descrição Função Período - Data de início  \
# 0       OfSuperior       OfSuperior               2023-01-10
# 1       OfIntermed       OfIntermed               2023-01-01
# 2       OfIntermed       OfIntermed               2023-01-01
# 3       OfIntermed       OfIntermed               2023-01-01
# 4       OfIntermed       OfIntermed               2023-01-01
# ...            ...              ...                      ...
# 387676          -1   Sem informação               2023-12-07
# 387677          -1   Sem informação               2023-12-07
# 387678          -1   Sem informação               2023-12-11
# 387679          -1   Sem informação               2023-12-11
# 387680          -1   Sem informação               2023-12-15
#
#        Período - Data de fim                             Destinos  \
# 0                 2023-01-29  Nova York/Estados Unidos da América
# 1                 2023-07-07                    Gotemburgo/Suécia
# 2                 2023-07-07                    Gotemburgo/Suécia
# 3                 2023-07-07                    Gotemburgo/Suécia
# 4                 2023-07-07                    Gotemburgo/Suécia
# ...                      ...                                  ...
# 387676            2023-12-08                       Sem informação
# 387677            2023-12-08                       Sem informação
# 387678            2023-12-11                       Sem informação
# 387679            2023-12-11                       Sem informação
# 387680            2023-12-18                       Sem informação
#
#                                                    Motivo  Valor diárias  \
# 0       Participar da revisão do COE Manual (Contingen...       39565.70
# 1            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# 2            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# 3            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# 4            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# ...                                                   ...            ...
# 387676     Acompanhamento do Presidente do BC - São Paulo         734.13
# 387677     Acompanhamento do Presidente do BC - São Paulo         734.13
# 387678          Acompanhamento do Presidente - São Paulo.         319.28
# 387679          Acompanhamento do Presidente - São Paulo.         319.28
# 387680                       Cumprir agenda em São Paulo.           0.00
#
#         Valor passagens  Valor devolução  Valor outros gastos  \
# 0               7434.13             0.00              1095.35
# 1              14903.10             0.00                 0.00
# 2              14903.10             0.00                 0.00
# 3              14903.10             0.00                 0.00
# 4              14903.10             0.00                 0.00
# ...                 ...              ...                  ...
# 387676          4555.95             0.00                 0.00
# 387677          4555.95             0.00                 0.00
# 387678          3745.53             0.00               400.00
# 387679          3745.53             0.00               400.00
# 387680          2961.55             0.00                 0.00
#
#         Despesas totais                       Cargos Mês da viagem  \
# 0              48095.18                Não informado       January
# 1              14903.10                Não informado       January
# 2              14903.10                Não informado       January
# 3              14903.10                Não informado       January
# 4              14903.10                Não informado       January
# ...                 ...                          ...           ...
# 387676          5290.08     TECNICO DO BANCO CENTRAL      December
# 387677          5290.08     TECNICO DO BANCO CENTRAL      December
# 387678          4464.81     TECNICO DO BANCO CENTRAL      December
# 387679          4464.81     TECNICO DO BANCO CENTRAL      December
# 387680          2961.55  PRESIDENTE DO BANCO CENTRAL      December
#
#         Dias de viagem Meio de transporte País - Origem ida   UF - Origem ida  \
# 0                   19              Aéreo            Brasil  Distrito Federal
# 1                  187              Aéreo            Brasil         São Paulo
# 2                  187              Aéreo            Brasil         São Paulo
# 3                  187              Aéreo            Brasil         São Paulo
# 4                  187              Aéreo            Brasil         São Paulo
# ...                ...                ...               ...               ...
# 387676               1              Aéreo            Brasil  Distrito Federal
# 387677               1              Aéreo            Brasil         São Paulo
# 387678               0              Aéreo            Brasil  Distrito Federal
# 387679               0              Aéreo            Brasil         São Paulo
# 387680               3              Aéreo            Brasil  Distrito Federal
#
#        Cidade - Origem ida         País - Destino ida  UF - Destino ida  \
# 0                 Brasília  Estados Unidos da América               NaN
# 1                São Paulo                     Suécia               NaN
# 2                São Paulo                     Suécia               NaN
# 3                São Paulo                     Suécia               NaN
# 4                São Paulo                     Suécia               NaN
# ...                    ...                        ...               ...
# 387676            Brasília                     Brasil         São Paulo
# 387677           São Paulo                     Brasil  Distrito Federal
# 387678            Brasília                     Brasil         São Paulo
# 387679           São Paulo                     Brasil  Distrito Federal
# 387680            Brasília                     Brasil         São Paulo
#
#        Cidade - Destino ida        País - Origem volta UF - Origem volta  \
# 0                 Nova York  Estados Unidos da América               NaN
# 1                Gotemburgo                     Suécia               NaN
# 2                Gotemburgo                     Suécia               NaN
# 3                Gotemburgo                     Suécia               NaN
# 4                Gotemburgo                     Suécia               NaN
# ...                     ...                        ...               ...
# 387676            São Paulo             Sem informação    Sem informação
# 387677             Brasília             Sem informação    Sem informação
# 387678            São Paulo             Sem informação    Sem informação
# 387679             Brasília             Sem informação    Sem informação
# 387680            São Paulo             Sem informação    Sem informação
#
#        Cidade - Origem volta Pais - Destino volta UF - Destino volta  \
# 0                  Nova York               Brasil   Distrito Federal
# 1                 Gotemburgo               Brasil          São Paulo
# 2                 Gotemburgo               Brasil          São Paulo
# 3                 Gotemburgo               Brasil          São Paulo
# 4                 Gotemburgo               Brasil          São Paulo
# ...                      ...                  ...                ...
# 387676        Sem informação       Sem informação     Sem informação
# 387677        Sem informação       Sem informação     Sem informação
# 387678        Sem informação       Sem informação     Sem informação
# 387679        Sem informação       Sem informação     Sem informação
# 387680        Sem informação       Sem informação     Sem informação
#
#        Cidade - Destino volta Valor da passagem Taxa de serviço  \
# 0                    Brasília           7434,13               0
# 1                   São Paulo           9903,32         4999,78
# 2                   São Paulo           9903,32         4999,78
# 3                   São Paulo           9903,32         4999,78
# 4                   São Paulo           9903,32         4999,78
# ...                       ...               ...             ...
# 387676         Sem informação           2791,41               0
# 387677         Sem informação           1764,54               0
# 387678         Sem informação           1985,65               0
# 387679         Sem informação           1759,88               0
# 387680         Sem informação           2961,55               0
#
#        Data da emissão/compra Hora da emissão/compra
# 0                  04/11/2022                  11:04
# 1                  15/09/2022                  13:39
# 2                  15/09/2022                  13:42
# 3                  15/09/2022                  13:51
# 4                  15/09/2022                  13:48
# ...                       ...                    ...
# 387676                    NaN                  00:00
# 387677                    NaN                  00:00
# 387678                    NaN                  00:00
# 387679                    NaN                  00:00
# 387680                    NaN                  00:00
#
# [387681 rows x 43 columns]

# %% [markdown]
# ## **Salvamento da tabela e gráfico no Google drive:**

# %%
Caminho_saida = "/content/drive/MyDrive/ASIMOV ACADEMY/PYTHON_PARA_DADOS/Conteúdo feito em aula/output/tabela.xlsx"

# %%
df_final.to_excel(Caminho_saida, index = False)

# %%
import matplotlib.pyplot as plt

Caminho_figura = "/content/drive/MyDrive/ASIMOV ACADEMY/PYTHON_PARA_DADOS/Conteúdo feito em aula/output/figura.png"

df_final = df_final.sort_values(by="Numero_de_viagens",ascending=False)

# Criando a figura
fig, ax = plt.subplots(figsize=(16, 6))

# Plotando o gráfico
ax.barh(df_final["Cargo"], df_final["Numero_de_viagens"], color = "#3ee679")
ax.invert_yaxis()

# Ajustando o gráfico
ax.set_facecolor("#1c273b")
fig.suptitle("Viagens por cargo público (2023)")
plt.figtext(0.89, 0.90, "Fonte: Portal da Transparência", fontsize=10, ha="right")
plt.grid(color = "gray", linestyle = "--", linewidth = "0.2")
plt.yticks(fontsize = 8)
plt.xlabel("Número de viagens")

# Exibindo o gráfico
plt.savefig(Caminho_figura, bbox_inches="tight")

# %% [markdown]
# ## **Daqui em diante será mostrado como foi a sequência do aprendizado para construção da tabela e gráfico:**

# %%
df_dados["Valor diárias"]
# Out:
# 0            0.00
# 1            0.00
# 2        39565.70
# 3         1013.96
# 4            0.00
#            ...
# 826984     606.89
# 826985    1089.00
# 826986     734.13
# 826987     319.28
# 826988       0.00
# Name: Valor diárias, Length: 826989, dtype: float64

# %%
colunas = ["Valor diárias" , "Valor passagens"]
df_dados[colunas]
# Out:
#         Valor diárias  Valor passagens
# 0                0.00             0.00
# 1                0.00             0.00
# 2            39565.70          7434.13
# 3             1013.96             0.00
# 4                0.00         14903.10
# ...               ...              ...
# 826984         606.89          3331.29
# 826985        1089.00          1837.18
# 826986         734.13          4555.95
# 826987         319.28          3745.53
# 826988           0.00          2961.55
#
# [826989 rows x 2 columns]

# %%
df_dados["Nome do órgão superior"].str.replace('Ministério','Min.').str.upper()
# Out:
# 0         MIN. DA EDUCAÇÃO
# 1         MIN. DA EDUCAÇÃO
# 2           MIN. DA DEFESA
# 3         MIN. DA EDUCAÇÃO
# 4           MIN. DA DEFESA
#                 ...
# 826984      SEM INFORMAÇÃO
# 826985      SEM INFORMAÇÃO
# 826986      SEM INFORMAÇÃO
# 826987      SEM INFORMAÇÃO
# 826988      SEM INFORMAÇÃO
# Name: Nome do órgão superior, Length: 826989, dtype: object

# %%
df_dados[["Valor diárias", "Valor passagens"]] # Usando dois colchetes evita-se criar uma variável.
# Out:
#         Valor diárias  Valor passagens
# 0                0.00             0.00
# 1                0.00             0.00
# 2            39565.70          7434.13
# 3             1013.96             0.00
# 4                0.00         14903.10
# ...               ...              ...
# 826984         606.89          3331.29
# 826985        1089.00          1837.18
# 826986         734.13          4555.95
# 826987         319.28          3745.53
# 826988           0.00          2961.55
#
# [826989 rows x 2 columns]

# %%
df_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 826989 entries, 0 to 826988
# Data columns (total 26 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Identificador do processo de viagem  826989 non-null  int64
#  1   Número da Proposta (PCDP)            826989 non-null  object
#  2   Situação                             826989 non-null  object
#  3   Viagem Urgente                       826989 non-null  object
#  4   Justificativa Urgência Viagem        826887 non-null  object
#  5   Código do órgão superior             826989 non-null  int64
#  6   Nome do órgão superior               826989 non-null  object
#  7   Código órgão solicitante             826989 non-null  int64
#  8   Nome órgão solicitante               826989 non-null  object
#  9   CPF viajante                         748302 non-null  object
#  10  Nome                                 826989 non-null  object
#  11  Cargo                                826989 non-null  object
#  12  Função                               826989 non-null  object
#  13  Descrição Função                     826977 non-null  object
#  14  Período - Data de início             826989 non-null  datetime64[ns]
#  15  Período - Data de fim                826989 non-null  datetime64[ns]
#  16  Destinos                             826989 non-null  object
#  17  Motivo                               826989 non-null  object
#  18  Valor diárias                        826989 non-null  float64
#  19  Valor passagens                      826989 non-null  float64
#  20  Valor devolução                      826989 non-null  float64
#  21  Valor outros gastos                  826989 non-null  float64
#  22  Despesas totais                      826989 non-null  float64
#  23  Cargos                               826989 non-null  object
#  24  Mês da viagem                        826989 non-null  object
#  25  Dias de viagem                       826989 non-null  int64
# dtypes: datetime64[ns](2), float64(5), int64(4), object(15)
# memory usage: 164.0+ MB

# %%
df_dados["Valor diárias"]
# Out:
# 0            0.00
# 1            0.00
# 2        39565.70
# 3         1013.96
# 4            0.00
#            ...
# 826984     606.89
# 826985    1089.00
# 826986     734.13
# 826987     319.28
# 826988       0.00
# Name: Valor diárias, Length: 826989, dtype: float64

# %%
df_dados["Valor diárias"] + df_dados["Valor passagens"]
# Out:
# 0            0.00
# 1            0.00
# 2        46999.83
# 3         1013.96
# 4        14903.10
#            ...
# 826984    3938.18
# 826985    2926.18
# 826986    5290.08
# 826987    4064.81
# 826988    2961.55
# Length: 826989, dtype: float64

# %%
df_dados["Despesas totais"] = df_dados["Valor diárias"] + df_dados["Valor passagens"] + df_dados["Valor outros gastos"]

# %%
df_dados["Despesas totais"]
# Out:
# 0            0.00
# 1            0.00
# 2        48095.18
# 3         1013.96
# 4        14903.10
#            ...
# 826984    3938.18
# 826985    2926.18
# 826986    5290.08
# 826987    4464.81
# 826988    2961.55
# Name: Despesas totais, Length: 826989, dtype: float64

# %%
df_dados # Repare que a coluna "Despesas totais" foi acrescentada na última coluna.
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18236583                 000018/23
# 2                                  18288418              000007/23-1C
# 3                                  18296348                 000070/23
# 4                                  18302983                 000001/23
# ...                                     ...                       ...
# 826984                           2023001618             Sem informaçã
# 826985                           2023001619             Sem informaçã
# 826986                           2023001628             Sem informaçã
# 826987                           2023001631             Sem informaçã
# 826988                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# 2       Realizada            SIM
# 3       Realizada            SIM
# 4       Realizada            NÃO
# ...           ...            ...
# 826984  Realizada            NÃO
# 826985  Realizada            NÃO
# 826986  Realizada            NÃO
# 826987  Realizada            NÃO
# 826988  Realizada            NÃO
#
#                             Justificativa Urgência Viagem  \
# 0                                          Sem informação
# 1                                          Sem informação
# 2                             Por necessidade do serviço.
# 3       A efetivação do empenho no Siafi e a respectiv...
# 4                                          Sem informação
# ...                                                   ...
# 826984                                     Sem informação
# 826985                                     Sem informação
# 826986                                     Sem informação
# 826987                                     Sem informação
# 826988                                     Sem informação
#
#         Código do órgão superior  Nome do órgão superior  \
# 0                          26000  Ministério da Educação
# 1                          26000  Ministério da Educação
# 2                          52000    Ministério da Defesa
# 3                          26000  Ministério da Educação
# 4                          52000    Ministério da Defesa
# ...                          ...                     ...
# 826984                        -1          Sem informação
# 826985                        -1          Sem informação
# 826986                        -1          Sem informação
# 826987                        -1          Sem informação
# 826988                        -1          Sem informação
#
#         Código órgão solicitante                Nome órgão solicitante  \
# 0                          26352  Fundação Universidade Federal do ABC
# 1                          26236       Universidade Federal Fluminense
# 2                          52121                   Comando do Exército
# 3                          26406   Instituto Federal do Espírito Santo
# 4                          52111                Comando da Aeronáutica
# ...                          ...                                   ...
# 826984                        -1                        Sem informação
# 826985                        -1                        Sem informação
# 826986                        -1                        Sem informação
# 826987                        -1                        Sem informação
# 826988                        -1                        Sem informação
#
#           CPF viajante                             Nome  \
# 0       ***.875.238-**           PRISCILA LEAL DA SILVA
# 1                  NaN          CAMILLA DUARTE DA SILVA
# 2       ***.621.358-**     ANDRE LUIS COSTA PITANGUEIRA
# 3       ***.407.547-**     LIDIANY MIRANDA FERRAZ NUNES
# 4       ***.855.388-**                    GREGOR GASPAR
# ...                ...                              ...
# 826984  ***.748.269-**               BIANCA VIANA KIVEL
# 826985  ***.231.806-**               LUCAS ALVES FREIRE
# 826986  ***.632.011-**                   SERGIO BOTELHO
# 826987  ***.407.445-**        NELSON CAMPOS REIS JUNIOR
# 826988  ***.602.017-**  ROBERTO DE OLIVEIRA CAMPOS NETO
#
#                                    Cargo      Função Descrição Função  \
# 0       PROFESSOR DO MAGISTERIO SUPERIOR          -1   Sem informação
# 1           BIBLIOTECARIO-DOCUMENTALISTA          -1   Sem informação
# 2                          Não informado  OfSuperior       OfSuperior
# 3                AUXILIAR DE BIBLIIOTECA          -1   Sem informação
# 4                          Não informado  OfIntermed       OfIntermed
# ...                                  ...         ...              ...
# 826984         ANALISTA DO BANCO CENTRAL          -1   Sem informação
# 826985       PROCURADOR DO BANCO CENTRAL          -1   Sem informação
# 826986          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826987          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826988       PRESIDENTE DO BANCO CENTRAL          -1   Sem informação
#
#        Período - Data de início Período - Data de fim  \
# 0                    2023-01-01            2023-12-02
# 1                    2023-01-16            2024-02-28
# 2                    2023-01-10            2023-01-29
# 3                    2023-02-05            2023-02-10
# 4                    2023-01-01            2023-07-07
# ...                         ...                   ...
# 826984               2023-12-05            2023-12-06
# 826985               2023-12-11            2023-12-13
# 826986               2023-12-07            2023-12-08
# 826987               2023-12-11            2023-12-11
# 826988               2023-12-15            2023-12-18
#
#                                    Destinos  \
# 0                  Loughborough/Reino Unido
# 1                         Rio de Janeiro/RJ
# 2       Nova York/Estados Unidos da América
# 3                                Vitória/ES
# 4                         Gotemburgo/Suécia
# ...                                     ...
# 826984                       Sem informação
# 826985                       Sem informação
# 826986                       Sem informação
# 826987                       Sem informação
# 826988                       Sem informação
#
#                                                    Motivo  Valor diárias  \
# 0            Intercâmbio acadêmico PCDP anterior 07/21-3C           0.00
# 1       Afastamento para pós-graduação stricto sensu n...           0.00
# 2       Participar da revisão do COE Manual (Contingen...       39565.70
# 3       Participação das aulas de Mestrado Interinstit...        1013.96
# 4            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# ...                                                   ...            ...
# 826984  Participar de tratativas nos locais das reuniõ...         606.89
# 826985                   Participar da reunião do COPOM .        1089.00
# 826986     Acompanhamento do Presidente do BC - São Paulo         734.13
# 826987          Acompanhamento do Presidente - São Paulo.         319.28
# 826988                       Cumprir agenda em São Paulo.           0.00
#
#         Valor passagens  Valor devolução  Valor outros gastos  \
# 0                  0.00             0.00                 0.00
# 1                  0.00             0.00                 0.00
# 2               7434.13             0.00              1095.35
# 3                  0.00             0.00                 0.00
# 4              14903.10             0.00                 0.00
# ...                 ...              ...                  ...
# 826984          3331.29             0.00                 0.00
# 826985          1837.18             0.00                 0.00
# 826986          4555.95             0.00                 0.00
# 826987          3745.53             0.00               400.00
# 826988          2961.55             0.00                 0.00
#
#         Despesas totais                            Cargos Mês da viagem  \
# 0                  0.00  PROFESSOR DO MAGISTERIO SUPERIOR       January
# 1                  0.00      BIBLIOTECARIO-DOCUMENTALISTA       January
# 2              48095.18                     Não informado       January
# 3               1013.96           AUXILIAR DE BIBLIIOTECA      February
# 4              14903.10                     Não informado       January
# ...                 ...                               ...           ...
# 826984          3938.18         ANALISTA DO BANCO CENTRAL      December
# 826985          2926.18       PROCURADOR DO BANCO CENTRAL      December
# 826986          5290.08          TECNICO DO BANCO CENTRAL      December
# 826987          4464.81          TECNICO DO BANCO CENTRAL      December
# 826988          2961.55       PRESIDENTE DO BANCO CENTRAL      December
#
#         Dias de viagem
# 0                  335
# 1                  408
# 2                   19
# 3                    5
# 4                  187
# ...                ...
# 826984               1
# 826985               2
# 826986               1
# 826987               0
# 826988               3
#
# [826989 rows x 26 columns]

# %%
df_dados["Cargo"].value_counts() # Conta a quantidade que o cargo aparece.
# Out:
# Cargo
# Não informado                            321835
# Informações protegidas por sigilo        118222
# PROFESSOR DO MAGISTERIO SUPERIOR          54570
# PROFESSOR ENS BASICO TECN TECNOLOGICO     37476
# CONTRATADO LEI 8745/93 - NI               17787
#                                           ...
# TECNICO EM HIGIENE DENTAL                     1
# OPERADOR DE TELE IMPRESSORA                   1
# ASSISTENTE TECNICO EM DESENV REGIONAL         1
# TECNICO DE MANUTENCAO                         1
# TECNICO DE CONTROLE DE PRIODUCAO              1
# Name: count, Length: 822, dtype: int64

# %%
df_dados["Cargo"].value_counts(normalize=True) # O "normalize=true" transforma os valores de %
                                               # para forma de índices.
# Out:
# Cargo
# Não informado                           0.39
# Informações protegidas por sigilo       0.14
# PROFESSOR DO MAGISTERIO SUPERIOR        0.07
# PROFESSOR ENS BASICO TECN TECNOLOGICO   0.05
# CONTRATADO LEI 8745/93 - NI             0.02
#                                         ...
# TECNICO EM HIGIENE DENTAL               0.00
# OPERADOR DE TELE IMPRESSORA             0.00
# ASSISTENTE TECNICO EM DESENV REGIONAL   0.00
# TECNICO DE MANUTENCAO                   0.00
# TECNICO DE CONTROLE DE PRIODUCAO        0.00
# Name: proportion, Length: 822, dtype: float64

# %%
pd.set_option('display.float_format', '{:.2f}'.format)   # A ação ".rename("Proporção de viagens").reset_index()" substitui "proportion" por "Proporções viagens" e cria-se nova coluna.
((df_dados["Cargo"].value_counts(normalize=True) * 100)).rename("Proporção de viagens").reset_index()
# Out:
#                                      Cargo  Proporção de viagens
# 0                            Não informado                 38.92
# 1        Informações protegidas por sigilo                 14.30
# 2         PROFESSOR DO MAGISTERIO SUPERIOR                  6.60
# 3    PROFESSOR ENS BASICO TECN TECNOLOGICO                  4.53
# 4              CONTRATADO LEI 8745/93 - NI                  2.15
# ..                                     ...                   ...
# 817              TECNICO EM HIGIENE DENTAL                  0.00
# 818            OPERADOR DE TELE IMPRESSORA                  0.00
# 819  ASSISTENTE TECNICO EM DESENV REGIONAL                  0.00
# 820                  TECNICO DE MANUTENCAO                  0.00
# 821       TECNICO DE CONTROLE DE PRIODUCAO                  0.00
#
# [822 rows x 2 columns]

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
df_dados.groupby("Cargo")["Despesas totais"].sum().reset_index().sort_values(by="Despesas totais",ascending=False)
# Out:
#                                      Cargo  Despesas totais
# 494                          Não informado    1049266194.86
# 443      Informações protegidas por sigilo     370919369.30
# 569       PROFESSOR DO MAGISTERIO SUPERIOR     110890764.22
# 570  PROFESSOR ENS BASICO TECN TECNOLOGICO      52548741.25
# 686               TECNICO DO SEGURO SOCIAL      45881679.92
# ..                                     ...              ...
# 734                  TECNICO EM METALURGIA             0.00
# 454                                LOCUTOR             0.00
# 566                      PROFESSOR ADJUNTO             0.00
# 818                               VIDREIRO             0.00
# 724                    TECNICO EM GEOLOGIA             0.00
#
# [822 rows x 2 columns]

# %%
df_dados.groupby("Cargo")["Despesas totais"].max().reset_index().sort_values(by="Despesas totais",ascending=False)
# Out:
#                                         Cargo  Despesas totais
# 480               MINISTRO DE PRIMEIRA CLASSE        195192.15
# 494                             Não informado        192676.02
# 443         Informações protegidas por sigilo        184787.42
# 542              PESQUISADOR EM SAUDE PUBLICA        172409.29
# 83       ANALISTA DE PLANEJAMENTO E ORCAMENTO        157255.53
# ..                                        ...              ...
# 220    AUXILIAR - AUXILIAR DE SERVICOS GERAIS             0.00
# 454                                   LOCUTOR             0.00
# 818                                  VIDREIRO             0.00
# 724                       TECNICO EM GEOLOGIA             0.00
# 152  ASG - OPERADOR DE MAQUINA E EQUIPAMENTOS             0.00
#
# [822 rows x 2 columns]

# %%
viagens_por_cargo = ((df_dados["Cargo"].value_counts(normalize=True) * 100)).rename("Proporção de viagens").reset_index()

# %%
filtro_1_pct = viagens_por_cargo ["Proporção de viagens"] > 1

# %%
viagens_por_cargo[filtro_1_pct]
# Out:
#                                        Cargo  Proporção de viagens
# 0                              Não informado                 38.92
# 1          Informações protegidas por sigilo                 14.30
# 2           PROFESSOR DO MAGISTERIO SUPERIOR                  6.60
# 3      PROFESSOR ENS BASICO TECN TECNOLOGICO                  4.53
# 4                CONTRATADO LEI 8745/93 - NI                  2.15
# 5        AUDITOR FISCAL FEDERAL AGROPECUARIO                  2.01
# 6                         ANALISTA AMBIENTAL                  1.65
# 7                ASSISTENTE EM ADMINISTRAçãO                  1.41
# 8    TECNICO INFOR GEOGRAFICAS E ESTATISTICA                  1.31
# 9                   TECNICO DO SEGURO SOCIAL                  1.29
# 10  AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL                  1.22
# 11    ANALISTA TRIBUTARIO REC FEDERAL BRASIL                  1.03

# %%
filtro_tecnico = viagens_por_cargo["Cargo"].str.startswith("TECNICO")

# %%
viagens_por_cargo[filtro_tecnico]
# Out:
#                                        Cargo  Proporção de viagens
# 8    TECNICO INFOR GEOGRAFICAS E ESTATISTICA                  1.31
# 9                   TECNICO DO SEGURO SOCIAL                  1.29
# 15                         TECNICO AMBIENTAL                  0.72
# 19                    TECNICO ADMINISTRATIVO                  0.53
# 24          TECNICO EM ASSUNTOS EDUCACIONAIS                  0.35
# ..                                       ...                   ...
# 803             TECNICO NM - 02 (DEC JUD-ME)                  0.00
# 814                    TECNICO EM MANUTENCAO                  0.00
# 817                TECNICO EM HIGIENE DENTAL                  0.00
# 820                    TECNICO DE MANUTENCAO                  0.00
# 821         TECNICO DE CONTROLE DE PRIODUCAO                  0.00
#
# [142 rows x 2 columns]

# %%
viagens_por_cargo[filtro_tecnico & filtro_1_pct] # O "&" equivale ao "and".
# Out:
#                                      Cargo  Proporção de viagens
# 8  TECNICO INFOR GEOGRAFICAS E ESTATISTICA                  1.31
# 9                 TECNICO DO SEGURO SOCIAL                  1.29

# %%
viagens_por_cargo[filtro_tecnico | filtro_1_pct] # O "|" equivale ao "or".
# Out:
#                                      Cargo  Proporção de viagens
# 0                            Não informado                 38.92
# 1        Informações protegidas por sigilo                 14.30
# 2         PROFESSOR DO MAGISTERIO SUPERIOR                  6.60
# 3    PROFESSOR ENS BASICO TECN TECNOLOGICO                  4.53
# 4              CONTRATADO LEI 8745/93 - NI                  2.15
# ..                                     ...                   ...
# 803           TECNICO NM - 02 (DEC JUD-ME)                  0.00
# 814                  TECNICO EM MANUTENCAO                  0.00
# 817              TECNICO EM HIGIENE DENTAL                  0.00
# 820                  TECNICO DE MANUTENCAO                  0.00
# 821       TECNICO DE CONTROLE DE PRIODUCAO                  0.00
#
# [152 rows x 2 columns]

# %%
gasto_totais_por_cargo = df_dados.groupby("Cargo")["Despesas totais"].sum().reset_index().sort_values(by="Despesas totais",ascending=False)

# %%
filtro_gastos_grandes = gasto_totais_por_cargo["Despesas totais"] > 10_000_000

# %%
gasto_totais_por_cargo[filtro_gastos_grandes]
# Out:
#                                         Cargo  Despesas totais
# 494                             Não informado    1049266194.86
# 443         Informações protegidas por sigilo     370919369.30
# 569          PROFESSOR DO MAGISTERIO SUPERIOR     110890764.22
# 570     PROFESSOR ENS BASICO TECN TECNOLOGICO      52548741.25
# 686                  TECNICO DO SEGURO SOCIAL      45881679.92
# 72                         ANALISTA AMBIENTAL      35344371.79
# 389   ESP EM REGULACAO E VIGILANCIA SANITARIA      24439537.06
# 209  AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL      24405946.47
# 208       AUDITOR FISCAL FEDERAL AGROPECUARIO      24306782.30
# 315               CONTRATADO LEI 8745/93 - NI      17510463.07
# 650                         TECNICO AMBIENTAL      17390362.57
# 95                  ANALISTA DO SEGURO SOCIAL      15988307.12
# 480               MINISTRO DE PRIMEIRA CLASSE      15868456.64
# 776   TECNICO INFOR GEOGRAFICAS E ESTATISTICA      15816641.46
# 179               ASSISTENTE EM ADMINISTRAçãO      15094703.63
# 15                      AGENTE ADMINISTRATIVO      15010847.19
# 113    ANALISTA TRIBUTARIO REC FEDERAL BRASIL      14868670.22
# 647                    TECNICO ADMINISTRATIVO      13394490.49
# 553                       PRIMEIRO SECRETARIO      12941870.25
# 386         ESP EM REGULACAO DE AVIACAO CIVIL      12716538.17
# 207                AUDITOR FISCAL DO TRABALHO      10376688.67
# 385     ESP EM REG DE SERV PUB DE TELECOMUNIC      10037621.59

# %%
# Surgerido no Curso sem criar uma vatiável a mais de filtro
gasto_totais_por_cargo[gasto_totais_por_cargo["Despesas totais"] > 10_000_000] # separador de milhar "_".

# Repetiu "gasto_totais_por_cargo" duas vezes. Desta forma evitou-se criar outro filtro
# como no exemplo acima.
# Out:
#                                         Cargo  Despesas totais
# 494                             Não informado    1049266194.86
# 443         Informações protegidas por sigilo     370919369.30
# 569          PROFESSOR DO MAGISTERIO SUPERIOR     110890764.22
# 570     PROFESSOR ENS BASICO TECN TECNOLOGICO      52548741.25
# 686                  TECNICO DO SEGURO SOCIAL      45881679.92
# 72                         ANALISTA AMBIENTAL      35344371.79
# 389   ESP EM REGULACAO E VIGILANCIA SANITARIA      24439537.06
# 209  AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL      24405946.47
# 208       AUDITOR FISCAL FEDERAL AGROPECUARIO      24306782.30
# 315               CONTRATADO LEI 8745/93 - NI      17510463.07
# 650                         TECNICO AMBIENTAL      17390362.57
# 95                  ANALISTA DO SEGURO SOCIAL      15988307.12
# 480               MINISTRO DE PRIMEIRA CLASSE      15868456.64
# 776   TECNICO INFOR GEOGRAFICAS E ESTATISTICA      15816641.46
# 179               ASSISTENTE EM ADMINISTRAçãO      15094703.63
# 15                      AGENTE ADMINISTRATIVO      15010847.19
# 113    ANALISTA TRIBUTARIO REC FEDERAL BRASIL      14868670.22
# 647                    TECNICO ADMINISTRATIVO      13394490.49
# 553                       PRIMEIRO SECRETARIO      12941870.25
# 386         ESP EM REGULACAO DE AVIACAO CIVIL      12716538.17
# 207                AUDITOR FISCAL DO TRABALHO      10376688.67
# 385     ESP EM REG DE SERV PUB DE TELECOMUNIC      10037621.59

# %%
# Ao trocar "sum()" por "mean()" calcula-se o gasto médio:
gasto_medio_por_cargo = df_dados.groupby("Cargo")["Despesas totais"].mean().reset_index().sort_values(by="Despesas totais",ascending=False)

# %%
gasto_medio_por_cargo[gasto_medio_por_cargo["Despesas totais"] > 10_000]
# Out:
#                                        Cargo  Despesas totais
# 616                          SEGUNDO TENENTE         40372.27
# 325    DELEGADO DE POLICIA - PRIMEIRA CLASSE         34105.32
# 617                          SEGUNDO-TENENTE         19820.29
# 480              MINISTRO DE PRIMEIRA CLASSE         19072.66
# 801                        TERCEIRO SARGENTO         19032.81
# 257            AUXILIAR DE SERVICOS DIVERSOS         19000.96
# 552                        PRIMEIRO SARGENTO         17509.58
# 3       AAD-AUXILIAR DE RECURSOS FINANCEIROS         15545.94
# 525   PAPILOSCOPISTA POLICIAL-SEGUNDA CLASSE         15421.69
# 481               MINISTRO DE SEGUNDA CLASSE         14458.99
# 553                      PRIMEIRO SECRETARIO         14036.74
# 230                AUXILIAR DE CONTABILIDADE         14015.48
# 37          AGENTE DE SERVICOS COMPLEMETARES         13975.38
# 781             TECNICO NM - 22 (DEC JUD-ME)         13720.12
# 389  ESP EM REGULACAO E VIGILANCIA SANITARIA         13013.60
# 402        ESPECIALISTA EM ATIV HOSPITALARES         12686.31
# 554                         PRIMEIRO TENENTE         12642.73
# 268            AUXILIAR NM - 06 (DEC JUD-ME)         12323.94
# 305                              CONSELHEIRO         12271.56
# 615                       SEGUNDO SECRETARIO         12103.76
# 802                      TERCEIRO SECRETARIO         11833.21
# 780             TECNICO NM - 21 (DEC JUD-ME)         11696.64
# 580                PROFISSIONAL ARTES SENICA         11642.59
# 499                   OFICIAL DE CHANCELARIA         11375.51
# 471              MEDICO PROGRAMA MAIS MEDICO         11367.61
# 559                       PRODUTOR EXECUTIVO         10410.95
# 170                ASSISTENTE DE CHANCELARIA         10356.99
# 657                       TECNICO DE ARQUIVO         10170.50

# %%
df_dados["Cargo"].value_counts(normalize=True).sum()
# Out:
# 1.0

# %%
df_dados["Cargo"].value_counts(dropna=False) # O "dropna=False" é uma forma de mostrar os valores nulos "NaN".
# "drop" significa derrubar e "na" valor nulo.
# Out:
# Cargo
# Não informado                            321835
# Informações protegidas por sigilo        118222
# PROFESSOR DO MAGISTERIO SUPERIOR          54570
# PROFESSOR ENS BASICO TECN TECNOLOGICO     37476
# CONTRATADO LEI 8745/93 - NI               17787
#                                           ...
# TECNICO EM HIGIENE DENTAL                     1
# OPERADOR DE TELE IMPRESSORA                   1
# ASSISTENTE TECNICO EM DESENV REGIONAL         1
# TECNICO DE MANUTENCAO                         1
# TECNICO DE CONTROLE DE PRIODUCAO              1
# Name: count, Length: 822, dtype: int64

# %%
# Vamos usar a tabela inteira agora
df_dados.dropna(subset=["Cargos"]) # eliminei os valores nulos somente na coluna "Cargo"
                                  # Aqui não usei "dropna=False". Por isso foi eliminado os nulos.

# A planilha que antes tinha "826989 rows × 23 columns" agora tem "505154 rows × 23 columns"
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18236583                 000018/23
# 2                                  18288418              000007/23-1C
# 3                                  18296348                 000070/23
# 4                                  18302983                 000001/23
# ...                                     ...                       ...
# 826984                           2023001618             Sem informaçã
# 826985                           2023001619             Sem informaçã
# 826986                           2023001628             Sem informaçã
# 826987                           2023001631             Sem informaçã
# 826988                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# 2       Realizada            SIM
# 3       Realizada            SIM
# 4       Realizada            NÃO
# ...           ...            ...
# 826984  Realizada            NÃO
# 826985  Realizada            NÃO
# 826986  Realizada            NÃO
# 826987  Realizada            NÃO
# 826988  Realizada            NÃO
#
#                             Justificativa Urgência Viagem  \
# 0                                          Sem informação
# 1                                          Sem informação
# 2                             Por necessidade do serviço.
# 3       A efetivação do empenho no Siafi e a respectiv...
# 4                                          Sem informação
# ...                                                   ...
# 826984                                     Sem informação
# 826985                                     Sem informação
# 826986                                     Sem informação
# 826987                                     Sem informação
# 826988                                     Sem informação
#
#         Código do órgão superior  Nome do órgão superior  \
# 0                          26000  Ministério da Educação
# 1                          26000  Ministério da Educação
# 2                          52000    Ministério da Defesa
# 3                          26000  Ministério da Educação
# 4                          52000    Ministério da Defesa
# ...                          ...                     ...
# 826984                        -1          Sem informação
# 826985                        -1          Sem informação
# 826986                        -1          Sem informação
# 826987                        -1          Sem informação
# 826988                        -1          Sem informação
#
#         Código órgão solicitante                Nome órgão solicitante  \
# 0                          26352  Fundação Universidade Federal do ABC
# 1                          26236       Universidade Federal Fluminense
# 2                          52121                   Comando do Exército
# 3                          26406   Instituto Federal do Espírito Santo
# 4                          52111                Comando da Aeronáutica
# ...                          ...                                   ...
# 826984                        -1                        Sem informação
# 826985                        -1                        Sem informação
# 826986                        -1                        Sem informação
# 826987                        -1                        Sem informação
# 826988                        -1                        Sem informação
#
#           CPF viajante                             Nome  \
# 0       ***.875.238-**           PRISCILA LEAL DA SILVA
# 1                  NaN          CAMILLA DUARTE DA SILVA
# 2       ***.621.358-**     ANDRE LUIS COSTA PITANGUEIRA
# 3       ***.407.547-**     LIDIANY MIRANDA FERRAZ NUNES
# 4       ***.855.388-**                    GREGOR GASPAR
# ...                ...                              ...
# 826984  ***.748.269-**               BIANCA VIANA KIVEL
# 826985  ***.231.806-**               LUCAS ALVES FREIRE
# 826986  ***.632.011-**                   SERGIO BOTELHO
# 826987  ***.407.445-**        NELSON CAMPOS REIS JUNIOR
# 826988  ***.602.017-**  ROBERTO DE OLIVEIRA CAMPOS NETO
#
#                                    Cargo      Função Descrição Função  \
# 0       PROFESSOR DO MAGISTERIO SUPERIOR          -1   Sem informação
# 1           BIBLIOTECARIO-DOCUMENTALISTA          -1   Sem informação
# 2                          Não informado  OfSuperior       OfSuperior
# 3                AUXILIAR DE BIBLIIOTECA          -1   Sem informação
# 4                          Não informado  OfIntermed       OfIntermed
# ...                                  ...         ...              ...
# 826984         ANALISTA DO BANCO CENTRAL          -1   Sem informação
# 826985       PROCURADOR DO BANCO CENTRAL          -1   Sem informação
# 826986          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826987          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826988       PRESIDENTE DO BANCO CENTRAL          -1   Sem informação
#
#        Período - Data de início Período - Data de fim  \
# 0                    2023-01-01            2023-12-02
# 1                    2023-01-16            2024-02-28
# 2                    2023-01-10            2023-01-29
# 3                    2023-02-05            2023-02-10
# 4                    2023-01-01            2023-07-07
# ...                         ...                   ...
# 826984               2023-12-05            2023-12-06
# 826985               2023-12-11            2023-12-13
# 826986               2023-12-07            2023-12-08
# 826987               2023-12-11            2023-12-11
# 826988               2023-12-15            2023-12-18
#
#                                    Destinos  \
# 0                  Loughborough/Reino Unido
# 1                         Rio de Janeiro/RJ
# 2       Nova York/Estados Unidos da América
# 3                                Vitória/ES
# 4                         Gotemburgo/Suécia
# ...                                     ...
# 826984                       Sem informação
# 826985                       Sem informação
# 826986                       Sem informação
# 826987                       Sem informação
# 826988                       Sem informação
#
#                                                    Motivo  Valor diárias  \
# 0            Intercâmbio acadêmico PCDP anterior 07/21-3C           0.00
# 1       Afastamento para pós-graduação stricto sensu n...           0.00
# 2       Participar da revisão do COE Manual (Contingen...       39565.70
# 3       Participação das aulas de Mestrado Interinstit...        1013.96
# 4            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# ...                                                   ...            ...
# 826984  Participar de tratativas nos locais das reuniõ...         606.89
# 826985                   Participar da reunião do COPOM .        1089.00
# 826986     Acompanhamento do Presidente do BC - São Paulo         734.13
# 826987          Acompanhamento do Presidente - São Paulo.         319.28
# 826988                       Cumprir agenda em São Paulo.           0.00
#
#         Valor passagens  Valor devolução  Valor outros gastos  \
# 0                  0.00             0.00                 0.00
# 1                  0.00             0.00                 0.00
# 2               7434.13             0.00              1095.35
# 3                  0.00             0.00                 0.00
# 4              14903.10             0.00                 0.00
# ...                 ...              ...                  ...
# 826984          3331.29             0.00                 0.00
# 826985          1837.18             0.00                 0.00
# 826986          4555.95             0.00                 0.00
# 826987          3745.53             0.00               400.00
# 826988          2961.55             0.00                 0.00
#
#         Despesas totais                            Cargos Mês da viagem  \
# 0                  0.00  PROFESSOR DO MAGISTERIO SUPERIOR       January
# 1                  0.00      BIBLIOTECARIO-DOCUMENTALISTA       January
# 2              48095.18                     Não informado       January
# 3               1013.96           AUXILIAR DE BIBLIIOTECA      February
# 4              14903.10                     Não informado       January
# ...                 ...                               ...           ...
# 826984          3938.18         ANALISTA DO BANCO CENTRAL      December
# 826985          2926.18       PROCURADOR DO BANCO CENTRAL      December
# 826986          5290.08          TECNICO DO BANCO CENTRAL      December
# 826987          4464.81          TECNICO DO BANCO CENTRAL      December
# 826988          2961.55       PRESIDENTE DO BANCO CENTRAL      December
#
#         Dias de viagem
# 0                  335
# 1                  408
# 2                   19
# 3                    5
# 4                  187
# ...                ...
# 826984               1
# 826985               2
# 826986               1
# 826987               0
# 826988               3
#
# [826989 rows x 26 columns]

# %%
# Agora em vez de eliminar irei preencher os "NaN" com outro nome.
df_dados["Cargo"].fillna("Não informado") # troquei o "dropna" por "fillna" seguido do texto entre parênteses.
# Out:
# 0         PROFESSOR DO MAGISTERIO SUPERIOR
# 1             BIBLIOTECARIO-DOCUMENTALISTA
# 2                            Não informado
# 3                  AUXILIAR DE BIBLIIOTECA
# 4                            Não informado
#                         ...
# 826984           ANALISTA DO BANCO CENTRAL
# 826985         PROCURADOR DO BANCO CENTRAL
# 826986            TECNICO DO BANCO CENTRAL
# 826987            TECNICO DO BANCO CENTRAL
# 826988         PRESIDENTE DO BANCO CENTRAL
# Name: Cargo, Length: 826989, dtype: object

# %%
df_dados.fillna("Não identificado") # Usando a planilha inteira
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18236583                 000018/23
# 2                                  18288418              000007/23-1C
# 3                                  18296348                 000070/23
# 4                                  18302983                 000001/23
# ...                                     ...                       ...
# 826984                           2023001618             Sem informaçã
# 826985                           2023001619             Sem informaçã
# 826986                           2023001628             Sem informaçã
# 826987                           2023001631             Sem informaçã
# 826988                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# 2       Realizada            SIM
# 3       Realizada            SIM
# 4       Realizada            NÃO
# ...           ...            ...
# 826984  Realizada            NÃO
# 826985  Realizada            NÃO
# 826986  Realizada            NÃO
# 826987  Realizada            NÃO
# 826988  Realizada            NÃO
#
#                             Justificativa Urgência Viagem  \
# 0                                          Sem informação
# 1                                          Sem informação
# 2                             Por necessidade do serviço.
# 3       A efetivação do empenho no Siafi e a respectiv...
# 4                                          Sem informação
# ...                                                   ...
# 826984                                     Sem informação
# 826985                                     Sem informação
# 826986                                     Sem informação
# 826987                                     Sem informação
# 826988                                     Sem informação
#
#         Código do órgão superior  Nome do órgão superior  \
# 0                          26000  Ministério da Educação
# 1                          26000  Ministério da Educação
# 2                          52000    Ministério da Defesa
# 3                          26000  Ministério da Educação
# 4                          52000    Ministério da Defesa
# ...                          ...                     ...
# 826984                        -1          Sem informação
# 826985                        -1          Sem informação
# 826986                        -1          Sem informação
# 826987                        -1          Sem informação
# 826988                        -1          Sem informação
#
#         Código órgão solicitante                Nome órgão solicitante  \
# 0                          26352  Fundação Universidade Federal do ABC
# 1                          26236       Universidade Federal Fluminense
# 2                          52121                   Comando do Exército
# 3                          26406   Instituto Federal do Espírito Santo
# 4                          52111                Comando da Aeronáutica
# ...                          ...                                   ...
# 826984                        -1                        Sem informação
# 826985                        -1                        Sem informação
# 826986                        -1                        Sem informação
# 826987                        -1                        Sem informação
# 826988                        -1                        Sem informação
#
#             CPF viajante                             Nome  \
# 0         ***.875.238-**           PRISCILA LEAL DA SILVA
# 1       Não identificado          CAMILLA DUARTE DA SILVA
# 2         ***.621.358-**     ANDRE LUIS COSTA PITANGUEIRA
# 3         ***.407.547-**     LIDIANY MIRANDA FERRAZ NUNES
# 4         ***.855.388-**                    GREGOR GASPAR
# ...                  ...                              ...
# 826984    ***.748.269-**               BIANCA VIANA KIVEL
# 826985    ***.231.806-**               LUCAS ALVES FREIRE
# 826986    ***.632.011-**                   SERGIO BOTELHO
# 826987    ***.407.445-**        NELSON CAMPOS REIS JUNIOR
# 826988    ***.602.017-**  ROBERTO DE OLIVEIRA CAMPOS NETO
#
#                                    Cargo      Função Descrição Função  \
# 0       PROFESSOR DO MAGISTERIO SUPERIOR          -1   Sem informação
# 1           BIBLIOTECARIO-DOCUMENTALISTA          -1   Sem informação
# 2                          Não informado  OfSuperior       OfSuperior
# 3                AUXILIAR DE BIBLIIOTECA          -1   Sem informação
# 4                          Não informado  OfIntermed       OfIntermed
# ...                                  ...         ...              ...
# 826984         ANALISTA DO BANCO CENTRAL          -1   Sem informação
# 826985       PROCURADOR DO BANCO CENTRAL          -1   Sem informação
# 826986          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826987          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826988       PRESIDENTE DO BANCO CENTRAL          -1   Sem informação
#
#        Período - Data de início Período - Data de fim  \
# 0                    2023-01-01            2023-12-02
# 1                    2023-01-16            2024-02-28
# 2                    2023-01-10            2023-01-29
# 3                    2023-02-05            2023-02-10
# 4                    2023-01-01            2023-07-07
# ...                         ...                   ...
# 826984               2023-12-05            2023-12-06
# 826985               2023-12-11            2023-12-13
# 826986               2023-12-07            2023-12-08
# 826987               2023-12-11            2023-12-11
# 826988               2023-12-15            2023-12-18
#
#                                    Destinos  \
# 0                  Loughborough/Reino Unido
# 1                         Rio de Janeiro/RJ
# 2       Nova York/Estados Unidos da América
# 3                                Vitória/ES
# 4                         Gotemburgo/Suécia
# ...                                     ...
# 826984                       Sem informação
# 826985                       Sem informação
# 826986                       Sem informação
# 826987                       Sem informação
# 826988                       Sem informação
#
#                                                    Motivo  Valor diárias  \
# 0            Intercâmbio acadêmico PCDP anterior 07/21-3C           0.00
# 1       Afastamento para pós-graduação stricto sensu n...           0.00
# 2       Participar da revisão do COE Manual (Contingen...       39565.70
# 3       Participação das aulas de Mestrado Interinstit...        1013.96
# 4            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# ...                                                   ...            ...
# 826984  Participar de tratativas nos locais das reuniõ...         606.89
# 826985                   Participar da reunião do COPOM .        1089.00
# 826986     Acompanhamento do Presidente do BC - São Paulo         734.13
# 826987          Acompanhamento do Presidente - São Paulo.         319.28
# 826988                       Cumprir agenda em São Paulo.           0.00
#
#         Valor passagens  Valor devolução  Valor outros gastos  \
# 0                  0.00             0.00                 0.00
# 1                  0.00             0.00                 0.00
# 2               7434.13             0.00              1095.35
# 3                  0.00             0.00                 0.00
# 4              14903.10             0.00                 0.00
# ...                 ...              ...                  ...
# 826984          3331.29             0.00                 0.00
# 826985          1837.18             0.00                 0.00
# 826986          4555.95             0.00                 0.00
# 826987          3745.53             0.00               400.00
# 826988          2961.55             0.00                 0.00
#
#         Despesas totais                            Cargos Mês da viagem  \
# 0                  0.00  PROFESSOR DO MAGISTERIO SUPERIOR       January
# 1                  0.00      BIBLIOTECARIO-DOCUMENTALISTA       January
# 2              48095.18                     Não informado       January
# 3               1013.96           AUXILIAR DE BIBLIIOTECA      February
# 4              14903.10                     Não informado       January
# ...                 ...                               ...           ...
# 826984          3938.18         ANALISTA DO BANCO CENTRAL      December
# 826985          2926.18       PROCURADOR DO BANCO CENTRAL      December
# 826986          5290.08          TECNICO DO BANCO CENTRAL      December
# 826987          4464.81          TECNICO DO BANCO CENTRAL      December
# 826988          2961.55       PRESIDENTE DO BANCO CENTRAL      December
#
#         Dias de viagem
# 0                  335
# 1                  408
# 2                   19
# 3                    5
# 4                  187
# ...                ...
# 826984               1
# 826985               2
# 826986               1
# 826987               0
# 826988               3
#
# [826989 rows x 26 columns]

# %%
# Ajustando valores nulos na coluna "Cargo"
df_dados["Cargos"] = df_dados["Cargo"].fillna("Não informado")
df_dados["Cargo"] = df_dados["Cargo"].fillna("Não informado")
df_dados # acrescentei sem querer uma nova coluna ao trocar "Cargo" por "Cargos" no plural.
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18236583                 000018/23
# 2                                  18288418              000007/23-1C
# 3                                  18296348                 000070/23
# 4                                  18302983                 000001/23
# ...                                     ...                       ...
# 826984                           2023001618             Sem informaçã
# 826985                           2023001619             Sem informaçã
# 826986                           2023001628             Sem informaçã
# 826987                           2023001631             Sem informaçã
# 826988                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# 2       Realizada            SIM
# 3       Realizada            SIM
# 4       Realizada            NÃO
# ...           ...            ...
# 826984  Realizada            NÃO
# 826985  Realizada            NÃO
# 826986  Realizada            NÃO
# 826987  Realizada            NÃO
# 826988  Realizada            NÃO
#
#                             Justificativa Urgência Viagem  \
# 0                                          Sem informação
# 1                                          Sem informação
# 2                             Por necessidade do serviço.
# 3       A efetivação do empenho no Siafi e a respectiv...
# 4                                          Sem informação
# ...                                                   ...
# 826984                                     Sem informação
# 826985                                     Sem informação
# 826986                                     Sem informação
# 826987                                     Sem informação
# 826988                                     Sem informação
#
#         Código do órgão superior  Nome do órgão superior  \
# 0                          26000  Ministério da Educação
# 1                          26000  Ministério da Educação
# 2                          52000    Ministério da Defesa
# 3                          26000  Ministério da Educação
# 4                          52000    Ministério da Defesa
# ...                          ...                     ...
# 826984                        -1          Sem informação
# 826985                        -1          Sem informação
# 826986                        -1          Sem informação
# 826987                        -1          Sem informação
# 826988                        -1          Sem informação
#
#         Código órgão solicitante                Nome órgão solicitante  \
# 0                          26352  Fundação Universidade Federal do ABC
# 1                          26236       Universidade Federal Fluminense
# 2                          52121                   Comando do Exército
# 3                          26406   Instituto Federal do Espírito Santo
# 4                          52111                Comando da Aeronáutica
# ...                          ...                                   ...
# 826984                        -1                        Sem informação
# 826985                        -1                        Sem informação
# 826986                        -1                        Sem informação
# 826987                        -1                        Sem informação
# 826988                        -1                        Sem informação
#
#           CPF viajante                             Nome  \
# 0       ***.875.238-**           PRISCILA LEAL DA SILVA
# 1                  NaN          CAMILLA DUARTE DA SILVA
# 2       ***.621.358-**     ANDRE LUIS COSTA PITANGUEIRA
# 3       ***.407.547-**     LIDIANY MIRANDA FERRAZ NUNES
# 4       ***.855.388-**                    GREGOR GASPAR
# ...                ...                              ...
# 826984  ***.748.269-**               BIANCA VIANA KIVEL
# 826985  ***.231.806-**               LUCAS ALVES FREIRE
# 826986  ***.632.011-**                   SERGIO BOTELHO
# 826987  ***.407.445-**        NELSON CAMPOS REIS JUNIOR
# 826988  ***.602.017-**  ROBERTO DE OLIVEIRA CAMPOS NETO
#
#                                    Cargo      Função Descrição Função  \
# 0       PROFESSOR DO MAGISTERIO SUPERIOR          -1   Sem informação
# 1           BIBLIOTECARIO-DOCUMENTALISTA          -1   Sem informação
# 2                          Não informado  OfSuperior       OfSuperior
# 3                AUXILIAR DE BIBLIIOTECA          -1   Sem informação
# 4                          Não informado  OfIntermed       OfIntermed
# ...                                  ...         ...              ...
# 826984         ANALISTA DO BANCO CENTRAL          -1   Sem informação
# 826985       PROCURADOR DO BANCO CENTRAL          -1   Sem informação
# 826986          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826987          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826988       PRESIDENTE DO BANCO CENTRAL          -1   Sem informação
#
#        Período - Data de início Período - Data de fim  \
# 0                    2023-01-01            2023-12-02
# 1                    2023-01-16            2024-02-28
# 2                    2023-01-10            2023-01-29
# 3                    2023-02-05            2023-02-10
# 4                    2023-01-01            2023-07-07
# ...                         ...                   ...
# 826984               2023-12-05            2023-12-06
# 826985               2023-12-11            2023-12-13
# 826986               2023-12-07            2023-12-08
# 826987               2023-12-11            2023-12-11
# 826988               2023-12-15            2023-12-18
#
#                                    Destinos  \
# 0                  Loughborough/Reino Unido
# 1                         Rio de Janeiro/RJ
# 2       Nova York/Estados Unidos da América
# 3                                Vitória/ES
# 4                         Gotemburgo/Suécia
# ...                                     ...
# 826984                       Sem informação
# 826985                       Sem informação
# 826986                       Sem informação
# 826987                       Sem informação
# 826988                       Sem informação
#
#                                                    Motivo  Valor diárias  \
# 0            Intercâmbio acadêmico PCDP anterior 07/21-3C           0.00
# 1       Afastamento para pós-graduação stricto sensu n...           0.00
# 2       Participar da revisão do COE Manual (Contingen...       39565.70
# 3       Participação das aulas de Mestrado Interinstit...        1013.96
# 4            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# ...                                                   ...            ...
# 826984  Participar de tratativas nos locais das reuniõ...         606.89
# 826985                   Participar da reunião do COPOM .        1089.00
# 826986     Acompanhamento do Presidente do BC - São Paulo         734.13
# 826987          Acompanhamento do Presidente - São Paulo.         319.28
# 826988                       Cumprir agenda em São Paulo.           0.00
#
#         Valor passagens  Valor devolução  Valor outros gastos  \
# 0                  0.00             0.00                 0.00
# 1                  0.00             0.00                 0.00
# 2               7434.13             0.00              1095.35
# 3                  0.00             0.00                 0.00
# 4              14903.10             0.00                 0.00
# ...                 ...              ...                  ...
# 826984          3331.29             0.00                 0.00
# 826985          1837.18             0.00                 0.00
# 826986          4555.95             0.00                 0.00
# 826987          3745.53             0.00               400.00
# 826988          2961.55             0.00                 0.00
#
#         Despesas totais                            Cargos Mês da viagem  \
# 0                  0.00  PROFESSOR DO MAGISTERIO SUPERIOR       January
# 1                  0.00      BIBLIOTECARIO-DOCUMENTALISTA       January
# 2              48095.18                     Não informado       January
# 3               1013.96           AUXILIAR DE BIBLIIOTECA      February
# 4              14903.10                     Não informado       January
# ...                 ...                               ...           ...
# 826984          3938.18         ANALISTA DO BANCO CENTRAL      December
# 826985          2926.18       PROCURADOR DO BANCO CENTRAL      December
# 826986          5290.08          TECNICO DO BANCO CENTRAL      December
# 826987          4464.81          TECNICO DO BANCO CENTRAL      December
# 826988          2961.55       PRESIDENTE DO BANCO CENTRAL      December
#
#         Dias de viagem
# 0                  335
# 1                  408
# 2                   19
# 3                    5
# 4                  187
# ...                ...
# 826984               1
# 826985               2
# 826986               1
# 826987               0
# 826988               3
#
# [826989 rows x 26 columns]

# %%
pd.to_datetime(df_dados["Período - Data de início"], format = "%d/%m/%Y")
# Out:
# 0        2023-01-01
# 1        2023-01-16
# 2        2023-01-10
# 3        2023-02-05
# 4        2023-01-01
#             ...
# 826984   2023-12-05
# 826985   2023-12-11
# 826986   2023-12-07
# 826987   2023-12-11
# 826988   2023-12-15
# Name: Período - Data de início, Length: 826989, dtype: datetime64[ns]

# %%
df_dados["Período - Data de início"] = pd.to_datetime(df_dados["Período - Data de início"], format = "%d/%m/%Y")
df_dados["Período - Data de fim"] = pd.to_datetime(df_dados["Período - Data de fim"], format = "%d/%m/%Y")

# %%
df_dados
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18236583                 000018/23
# 2                                  18288418              000007/23-1C
# 3                                  18296348                 000070/23
# 4                                  18302983                 000001/23
# ...                                     ...                       ...
# 826984                           2023001618             Sem informaçã
# 826985                           2023001619             Sem informaçã
# 826986                           2023001628             Sem informaçã
# 826987                           2023001631             Sem informaçã
# 826988                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# 2       Realizada            SIM
# 3       Realizada            SIM
# 4       Realizada            NÃO
# ...           ...            ...
# 826984  Realizada            NÃO
# 826985  Realizada            NÃO
# 826986  Realizada            NÃO
# 826987  Realizada            NÃO
# 826988  Realizada            NÃO
#
#                             Justificativa Urgência Viagem  \
# 0                                          Sem informação
# 1                                          Sem informação
# 2                             Por necessidade do serviço.
# 3       A efetivação do empenho no Siafi e a respectiv...
# 4                                          Sem informação
# ...                                                   ...
# 826984                                     Sem informação
# 826985                                     Sem informação
# 826986                                     Sem informação
# 826987                                     Sem informação
# 826988                                     Sem informação
#
#         Código do órgão superior  Nome do órgão superior  \
# 0                          26000  Ministério da Educação
# 1                          26000  Ministério da Educação
# 2                          52000    Ministério da Defesa
# 3                          26000  Ministério da Educação
# 4                          52000    Ministério da Defesa
# ...                          ...                     ...
# 826984                        -1          Sem informação
# 826985                        -1          Sem informação
# 826986                        -1          Sem informação
# 826987                        -1          Sem informação
# 826988                        -1          Sem informação
#
#         Código órgão solicitante                Nome órgão solicitante  \
# 0                          26352  Fundação Universidade Federal do ABC
# 1                          26236       Universidade Federal Fluminense
# 2                          52121                   Comando do Exército
# 3                          26406   Instituto Federal do Espírito Santo
# 4                          52111                Comando da Aeronáutica
# ...                          ...                                   ...
# 826984                        -1                        Sem informação
# 826985                        -1                        Sem informação
# 826986                        -1                        Sem informação
# 826987                        -1                        Sem informação
# 826988                        -1                        Sem informação
#
#           CPF viajante                             Nome  \
# 0       ***.875.238-**           PRISCILA LEAL DA SILVA
# 1                  NaN          CAMILLA DUARTE DA SILVA
# 2       ***.621.358-**     ANDRE LUIS COSTA PITANGUEIRA
# 3       ***.407.547-**     LIDIANY MIRANDA FERRAZ NUNES
# 4       ***.855.388-**                    GREGOR GASPAR
# ...                ...                              ...
# 826984  ***.748.269-**               BIANCA VIANA KIVEL
# 826985  ***.231.806-**               LUCAS ALVES FREIRE
# 826986  ***.632.011-**                   SERGIO BOTELHO
# 826987  ***.407.445-**        NELSON CAMPOS REIS JUNIOR
# 826988  ***.602.017-**  ROBERTO DE OLIVEIRA CAMPOS NETO
#
#                                    Cargo      Função Descrição Função  \
# 0       PROFESSOR DO MAGISTERIO SUPERIOR          -1   Sem informação
# 1           BIBLIOTECARIO-DOCUMENTALISTA          -1   Sem informação
# 2                          Não informado  OfSuperior       OfSuperior
# 3                AUXILIAR DE BIBLIIOTECA          -1   Sem informação
# 4                          Não informado  OfIntermed       OfIntermed
# ...                                  ...         ...              ...
# 826984         ANALISTA DO BANCO CENTRAL          -1   Sem informação
# 826985       PROCURADOR DO BANCO CENTRAL          -1   Sem informação
# 826986          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826987          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826988       PRESIDENTE DO BANCO CENTRAL          -1   Sem informação
#
#        Período - Data de início Período - Data de fim  \
# 0                    2023-01-01            2023-12-02
# 1                    2023-01-16            2024-02-28
# 2                    2023-01-10            2023-01-29
# 3                    2023-02-05            2023-02-10
# 4                    2023-01-01            2023-07-07
# ...                         ...                   ...
# 826984               2023-12-05            2023-12-06
# 826985               2023-12-11            2023-12-13
# 826986               2023-12-07            2023-12-08
# 826987               2023-12-11            2023-12-11
# 826988               2023-12-15            2023-12-18
#
#                                    Destinos  \
# 0                  Loughborough/Reino Unido
# 1                         Rio de Janeiro/RJ
# 2       Nova York/Estados Unidos da América
# 3                                Vitória/ES
# 4                         Gotemburgo/Suécia
# ...                                     ...
# 826984                       Sem informação
# 826985                       Sem informação
# 826986                       Sem informação
# 826987                       Sem informação
# 826988                       Sem informação
#
#                                                    Motivo  Valor diárias  \
# 0            Intercâmbio acadêmico PCDP anterior 07/21-3C           0.00
# 1       Afastamento para pós-graduação stricto sensu n...           0.00
# 2       Participar da revisão do COE Manual (Contingen...       39565.70
# 3       Participação das aulas de Mestrado Interinstit...        1013.96
# 4            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# ...                                                   ...            ...
# 826984  Participar de tratativas nos locais das reuniõ...         606.89
# 826985                   Participar da reunião do COPOM .        1089.00
# 826986     Acompanhamento do Presidente do BC - São Paulo         734.13
# 826987          Acompanhamento do Presidente - São Paulo.         319.28
# 826988                       Cumprir agenda em São Paulo.           0.00
#
#         Valor passagens  Valor devolução  Valor outros gastos  \
# 0                  0.00             0.00                 0.00
# 1                  0.00             0.00                 0.00
# 2               7434.13             0.00              1095.35
# 3                  0.00             0.00                 0.00
# 4              14903.10             0.00                 0.00
# ...                 ...              ...                  ...
# 826984          3331.29             0.00                 0.00
# 826985          1837.18             0.00                 0.00
# 826986          4555.95             0.00                 0.00
# 826987          3745.53             0.00               400.00
# 826988          2961.55             0.00                 0.00
#
#         Despesas totais                            Cargos Mês da viagem  \
# 0                  0.00  PROFESSOR DO MAGISTERIO SUPERIOR       January
# 1                  0.00      BIBLIOTECARIO-DOCUMENTALISTA       January
# 2              48095.18                     Não informado       January
# 3               1013.96           AUXILIAR DE BIBLIIOTECA      February
# 4              14903.10                     Não informado       January
# ...                 ...                               ...           ...
# 826984          3938.18         ANALISTA DO BANCO CENTRAL      December
# 826985          2926.18       PROCURADOR DO BANCO CENTRAL      December
# 826986          5290.08          TECNICO DO BANCO CENTRAL      December
# 826987          4464.81          TECNICO DO BANCO CENTRAL      December
# 826988          2961.55       PRESIDENTE DO BANCO CENTRAL      December
#
#         Dias de viagem
# 0                  335
# 1                  408
# 2                   19
# 3                    5
# 4                  187
# ...                ...
# 826984               1
# 826985               2
# 826986               1
# 826987               0
# 826988               3
#
# [826989 rows x 26 columns]

# %%
df_dados["Mês da viagem"] = df_dados["Período - Data de início"].dt.month_name()

# %%
df_dados["Período - Data de fim"] - df_dados["Período - Data de início"]
# Out:
# 0        335 days
# 1        408 days
# 2         19 days
# 3          5 days
# 4        187 days
#            ...
# 826984     1 days
# 826985     2 days
# 826986     1 days
# 826987     0 days
# 826988     3 days
# Length: 826989, dtype: timedelta64[ns]

# %%
(df_dados["Período - Data de fim"] - df_dados["Período - Data de início"]).dt.days
# Out:
# 0         335
# 1         408
# 2          19
# 3           5
# 4         187
#          ...
# 826984      1
# 826985      2
# 826986      1
# 826987      0
# 826988      3
# Length: 826989, dtype: int64

# %%
df_dados["Dias de viagem"] = (df_dados["Período - Data de fim"] - df_dados["Período - Data de início"]).dt.days

# %%
df_dados # repare que foi acrescentado a coluna "Dias de viagem"
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18236583                 000018/23
# 2                                  18288418              000007/23-1C
# 3                                  18296348                 000070/23
# 4                                  18302983                 000001/23
# ...                                     ...                       ...
# 826984                           2023001618             Sem informaçã
# 826985                           2023001619             Sem informaçã
# 826986                           2023001628             Sem informaçã
# 826987                           2023001631             Sem informaçã
# 826988                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# 2       Realizada            SIM
# 3       Realizada            SIM
# 4       Realizada            NÃO
# ...           ...            ...
# 826984  Realizada            NÃO
# 826985  Realizada            NÃO
# 826986  Realizada            NÃO
# 826987  Realizada            NÃO
# 826988  Realizada            NÃO
#
#                             Justificativa Urgência Viagem  \
# 0                                          Sem informação
# 1                                          Sem informação
# 2                             Por necessidade do serviço.
# 3       A efetivação do empenho no Siafi e a respectiv...
# 4                                          Sem informação
# ...                                                   ...
# 826984                                     Sem informação
# 826985                                     Sem informação
# 826986                                     Sem informação
# 826987                                     Sem informação
# 826988                                     Sem informação
#
#         Código do órgão superior  Nome do órgão superior  \
# 0                          26000  Ministério da Educação
# 1                          26000  Ministério da Educação
# 2                          52000    Ministério da Defesa
# 3                          26000  Ministério da Educação
# 4                          52000    Ministério da Defesa
# ...                          ...                     ...
# 826984                        -1          Sem informação
# 826985                        -1          Sem informação
# 826986                        -1          Sem informação
# 826987                        -1          Sem informação
# 826988                        -1          Sem informação
#
#         Código órgão solicitante                Nome órgão solicitante  \
# 0                          26352  Fundação Universidade Federal do ABC
# 1                          26236       Universidade Federal Fluminense
# 2                          52121                   Comando do Exército
# 3                          26406   Instituto Federal do Espírito Santo
# 4                          52111                Comando da Aeronáutica
# ...                          ...                                   ...
# 826984                        -1                        Sem informação
# 826985                        -1                        Sem informação
# 826986                        -1                        Sem informação
# 826987                        -1                        Sem informação
# 826988                        -1                        Sem informação
#
#           CPF viajante                             Nome  \
# 0       ***.875.238-**           PRISCILA LEAL DA SILVA
# 1                  NaN          CAMILLA DUARTE DA SILVA
# 2       ***.621.358-**     ANDRE LUIS COSTA PITANGUEIRA
# 3       ***.407.547-**     LIDIANY MIRANDA FERRAZ NUNES
# 4       ***.855.388-**                    GREGOR GASPAR
# ...                ...                              ...
# 826984  ***.748.269-**               BIANCA VIANA KIVEL
# 826985  ***.231.806-**               LUCAS ALVES FREIRE
# 826986  ***.632.011-**                   SERGIO BOTELHO
# 826987  ***.407.445-**        NELSON CAMPOS REIS JUNIOR
# 826988  ***.602.017-**  ROBERTO DE OLIVEIRA CAMPOS NETO
#
#                                    Cargo      Função Descrição Função  \
# 0       PROFESSOR DO MAGISTERIO SUPERIOR          -1   Sem informação
# 1           BIBLIOTECARIO-DOCUMENTALISTA          -1   Sem informação
# 2                          Não informado  OfSuperior       OfSuperior
# 3                AUXILIAR DE BIBLIIOTECA          -1   Sem informação
# 4                          Não informado  OfIntermed       OfIntermed
# ...                                  ...         ...              ...
# 826984         ANALISTA DO BANCO CENTRAL          -1   Sem informação
# 826985       PROCURADOR DO BANCO CENTRAL          -1   Sem informação
# 826986          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826987          TECNICO DO BANCO CENTRAL          -1   Sem informação
# 826988       PRESIDENTE DO BANCO CENTRAL          -1   Sem informação
#
#        Período - Data de início Período - Data de fim  \
# 0                    2023-01-01            2023-12-02
# 1                    2023-01-16            2024-02-28
# 2                    2023-01-10            2023-01-29
# 3                    2023-02-05            2023-02-10
# 4                    2023-01-01            2023-07-07
# ...                         ...                   ...
# 826984               2023-12-05            2023-12-06
# 826985               2023-12-11            2023-12-13
# 826986               2023-12-07            2023-12-08
# 826987               2023-12-11            2023-12-11
# 826988               2023-12-15            2023-12-18
#
#                                    Destinos  \
# 0                  Loughborough/Reino Unido
# 1                         Rio de Janeiro/RJ
# 2       Nova York/Estados Unidos da América
# 3                                Vitória/ES
# 4                         Gotemburgo/Suécia
# ...                                     ...
# 826984                       Sem informação
# 826985                       Sem informação
# 826986                       Sem informação
# 826987                       Sem informação
# 826988                       Sem informação
#
#                                                    Motivo  Valor diárias  \
# 0            Intercâmbio acadêmico PCDP anterior 07/21-3C           0.00
# 1       Afastamento para pós-graduação stricto sensu n...           0.00
# 2       Participar da revisão do COE Manual (Contingen...       39565.70
# 3       Participação das aulas de Mestrado Interinstit...        1013.96
# 4            PARTICIPAR DO CURSO DE PILOTO DE GRIPEN C/D.           0.00
# ...                                                   ...            ...
# 826984  Participar de tratativas nos locais das reuniõ...         606.89
# 826985                   Participar da reunião do COPOM .        1089.00
# 826986     Acompanhamento do Presidente do BC - São Paulo         734.13
# 826987          Acompanhamento do Presidente - São Paulo.         319.28
# 826988                       Cumprir agenda em São Paulo.           0.00
#
#         Valor passagens  Valor devolução  Valor outros gastos  \
# 0                  0.00             0.00                 0.00
# 1                  0.00             0.00                 0.00
# 2               7434.13             0.00              1095.35
# 3                  0.00             0.00                 0.00
# 4              14903.10             0.00                 0.00
# ...                 ...              ...                  ...
# 826984          3331.29             0.00                 0.00
# 826985          1837.18             0.00                 0.00
# 826986          4555.95             0.00                 0.00
# 826987          3745.53             0.00               400.00
# 826988          2961.55             0.00                 0.00
#
#         Despesas totais                            Cargos Mês da viagem  \
# 0                  0.00  PROFESSOR DO MAGISTERIO SUPERIOR       January
# 1                  0.00      BIBLIOTECARIO-DOCUMENTALISTA       January
# 2              48095.18                     Não informado       January
# 3               1013.96           AUXILIAR DE BIBLIIOTECA      February
# 4              14903.10                     Não informado       January
# ...                 ...                               ...           ...
# 826984          3938.18         ANALISTA DO BANCO CENTRAL      December
# 826985          2926.18       PROCURADOR DO BANCO CENTRAL      December
# 826986          5290.08          TECNICO DO BANCO CENTRAL      December
# 826987          4464.81          TECNICO DO BANCO CENTRAL      December
# 826988          2961.55       PRESIDENTE DO BANCO CENTRAL      December
#
#         Dias de viagem
# 0                  335
# 1                  408
# 2                   19
# 3                    5
# 4                  187
# ...                ...
# 826984               1
# 826985               2
# 826986               1
# 826987               0
# 826988               3
#
# [826989 rows x 26 columns]

# %%
dias_de_viagem_por_cargo = df_dados.groupby("Cargo")["Dias de viagem"].mean().reset_index().sort_values(by="Dias de viagem",ascending=False)

# %%
dias_de_viagem_por_cargo
# Out:
#                                      Cargo  Dias de viagem
# 616                        SEGUNDO TENENTE          163.30
# 325  DELEGADO DE POLICIA - PRIMEIRA CLASSE          125.00
# 801                      TERCEIRO SARGENTO           71.67
# 617                        SEGUNDO-TENENTE           65.50
# 552                      PRIMEIRO SARGENTO           64.68
# ..                                     ...             ...
# 338                      DIRETOR DE IMAGEM            0.00
# 128                    ARQUIVISTA DE TAPES            0.00
# 447                       JORNALISTA - 25H            0.00
# 169                   ASSISTENTE DE CAMERA            0.00
# 518     OPERADOR DE RADIO TELECOMUNICA??ES            0.00
#
# [822 rows x 2 columns]

# %%
dias_de_viagem_por_cargo_maximo = df_dados.groupby("Cargo")["Dias de viagem"].max().reset_index().sort_values(by="Dias de viagem",ascending=False)

# %%
dias_de_viagem_por_cargo_maximo
# Out:
#                                        Cargo  Dias de viagem
# 443        Informações protegidas por sigilo             501
# 569         PROFESSOR DO MAGISTERIO SUPERIOR             455
# 12                         ADVOGADO DA UNIAO             425
# 289             BIBLIOTECARIO-DOCUMENTALISTA             408
# 494                            Não informado             402
# ..                                       ...             ...
# 732                    TECNICO EM MANUTENCAO               0
# 119             APOIO OPERACIONAL A PRODUCAO               0
# 746  TECNICO EM PRESERVACAO ARQUITETONICA II               0
# 751           TECNICO EM RADIOLOGIA 24 HORAS               0
# 635    TEC EM ENFERMAGEM SAUDE DO TRAB - 40H               0
#
# [822 rows x 2 columns]

# %%
(
    df_dados
    .groupby("Cargo")
    .agg(
        Despesa_media=("Despesas totais", "mean"),
        Dias_de_viagem_medio=("Dias de viagem", "mean"),
        Despesas_soma=("Despesas totais", "sum"),
        Destinos_mais_frequentes=("Destinos", pd.Series.mode), # esse comando calcula a "moda" de cada cargo, ou seja, o valor que mais repete..
        Numero_de_viagens=("Destinos", "count")
        )
    .reset_index()
    .sort_values(by="Despesa_media",ascending=False)
    )
# Out:
#                                         Cargo  Despesa_media  \
# 616                           SEGUNDO TENENTE       40372.27
# 325     DELEGADO DE POLICIA - PRIMEIRA CLASSE       34105.32
# 617                           SEGUNDO-TENENTE       19820.29
# 480               MINISTRO DE PRIMEIRA CLASSE       19072.66
# 801                         TERCEIRO SARGENTO       19032.81
# ..                                        ...            ...
# 220    AUXILIAR - AUXILIAR DE SERVICOS GERAIS           0.00
# 566                         PROFESSOR ADJUNTO           0.00
# 152  ASG - OPERADOR DE MAQUINA E EQUIPAMENTOS           0.00
# 818                                  VIDREIRO           0.00
# 734                     TECNICO EM METALURGIA           0.00
#
#      Dias_de_viagem_medio  Despesas_soma  \
# 616                163.30      403722.70
# 325                125.00       34105.32
# 617                 65.50      158562.30
# 480                  5.93    15868456.64
# 801                 71.67      685180.98
# ..                    ...            ...
# 220                  7.71           0.00
# 566                  5.00           0.00
# 152                  8.00           0.00
# 818                  6.00           0.00
# 734                  3.00           0.00
#
#                               Destinos_mais_frequentes  Numero_de_viagens
# 616  [Amambaí/MS, Juína/MT, Colniza/MT, Juína/MT, P...                 10
# 325  São Paulo/SP, Santos/SP, São Paulo/SP, São Pau...                  1
# 617                          [Calçoene/AP, Itaubal/AP]                  8
# 480                                        Brasília/DF                832
# 801                                         Aracaju/SE                 36
# ..                                                 ...                ...
# 220                         [Ponta Porã/MS, Tacuru/MS]                  7
# 566                             Buenos Aires/Argentina                  1
# 152                                          Guaíra/PR                  1
# 818                                        Brasília/DF                  1
# 734                           [Alumínio/SP, Maceió/AL]                  2
#
# [822 rows x 6 columns]

# %%
df_cargos = df_dados["Cargo"].value_counts(normalize=True).reset_index()
df_cargos
# Out:
#                                      Cargo  proportion
# 0                            Não informado        0.39
# 1        Informações protegidas por sigilo        0.14
# 2         PROFESSOR DO MAGISTERIO SUPERIOR        0.07
# 3    PROFESSOR ENS BASICO TECN TECNOLOGICO        0.05
# 4              CONTRATADO LEI 8745/93 - NI        0.02
# ..                                     ...         ...
# 817              TECNICO EM HIGIENE DENTAL        0.00
# 818            OPERADOR DE TELE IMPRESSORA        0.00
# 819  ASSISTENTE TECNICO EM DESENV REGIONAL        0.00
# 820                  TECNICO DE MANUTENCAO        0.00
# 821       TECNICO DE CONTROLE DE PRIODUCAO        0.00
#
# [822 rows x 2 columns]

# %% [markdown]
# ###No Pandas, o **" loc "** é um atributo usado para acessar grupos de linhas e colunas em um DataFrame ou Series, baseado em rótulos ou em uma condição booleana. Ele permite realizar seleção e manipulação de dados de forma eficiente.
#
# **Ex: df.loc [ linhas, colunas ]**

# %%
df_cargos.loc[df_cargos["proportion"] > 0.01, "Cargo"] # Ao especificar "Cargo" no final, selecion-se somente
                                                       # a coluna "Cargo" com os parâmetros da coluna "proportion", como no ProcV do Excel.
# Out:
# 0                                Não informado
# 1            Informações protegidas por sigilo
# 2             PROFESSOR DO MAGISTERIO SUPERIOR
# 3        PROFESSOR ENS BASICO TECN TECNOLOGICO
# 4                  CONTRATADO LEI 8745/93 - NI
# 5          AUDITOR FISCAL FEDERAL AGROPECUARIO
# 6                           ANALISTA AMBIENTAL
# 7                  ASSISTENTE EM ADMINISTRAçãO
# 8      TECNICO INFOR GEOGRAFICAS E ESTATISTICA
# 9                     TECNICO DO SEGURO SOCIAL
# 10    AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL
# 11      ANALISTA TRIBUTARIO REC FEDERAL BRASIL
# Name: Cargo, dtype: object

# %%
df_dados_consolidado = (
    df_dados
    .groupby("Cargo")
    .agg(
        Despesa_media=("Despesas totais", "mean"),
        Dias_de_viagem_medio=("Dias de viagem", "mean"),
        Despesas_soma=("Despesas totais", "sum"),
        Destinos_mais_frequentes=("Destinos", pd.Series.mode),
        Numero_de_viagens=("Destinos", "count")
        )
    .reset_index()
    .sort_values(by="Despesa_media",ascending=False)
    )

# %%
cargos_relevantes = df_cargos.loc[df_cargos["proportion"] > 0.01, "Cargo"]

# %%
df_dados_consolidado["Cargo"].isin(cargos_relevantes)
# Out:
# 616    False
# 325    False
# 617    False
# 480    False
# 801    False
#        ...
# 220    False
# 566    False
# 152    False
# 818    False
# 734    False
# Name: Cargo, Length: 822, dtype: bool

# %%
# Posso criar uma variável para o filtro gerado acima e em seguida aplicá-lo:
filtro = df_dados_consolidado["Cargo"].isin(cargos_relevantes)

df_dados_consolidado[filtro].sort_values(by="Despesa_media",ascending=False) # ordenei pela coluna "Despesa_media".
# Out:
#                                         Cargo  Despesa_media  \
# 686                  TECNICO DO SEGURO SOCIAL        4302.48
# 494                             Não informado        3260.26
# 443         Informações protegidas por sigilo        3137.48
# 72                         ANALISTA AMBIENTAL        2596.94
# 209  AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL        2418.11
# 569          PROFESSOR DO MAGISTERIO SUPERIOR        2032.08
# 113    ANALISTA TRIBUTARIO REC FEDERAL BRASIL        1746.79
# 208       AUDITOR FISCAL FEDERAL AGROPECUARIO        1465.85
# 776   TECNICO INFOR GEOGRAFICAS E ESTATISTICA        1457.08
# 570     PROFESSOR ENS BASICO TECN TECNOLOGICO        1402.20
# 179               ASSISTENTE EM ADMINISTRAçãO        1291.03
# 315               CONTRATADO LEI 8745/93 - NI         984.45
#
#      Dias_de_viagem_medio  Despesas_soma           Destinos_mais_frequentes  \
# 686                 11.37    45881679.92                        Brasília/DF
# 494                  8.01  1049266194.86                        Brasília/DF
# 443                  7.41   370919369.30  Informações protegidas por sigilo
# 72                   5.13    35344371.79                        Brasília/DF
# 209                  2.84    24405946.47                        Brasília/DF
# 569                  3.87   110890764.22                        Brasília/DF
# 113                  3.06    14868670.22                   Foz do Iguaçu/PR
# 208                  2.06    24306782.30                        Brasília/DF
# 776                  3.19    15816641.46                        Brasília/DF
# 570                  2.34    52548741.25                        Brasília/DF
# 179                  2.17    15094703.63                        Brasília/DF
# 315                  2.84    17510463.07                           Bauru/SP
#
#      Numero_de_viagens
# 686              10664
# 494             321835
# 443             118222
# 72               13610
# 209              10093
# 569              54570
# 113               8512
# 208              16582
# 776              10855
# 570              37476
# 179              11692
# 315              17787

# %%
# Ou posso fazer sem filtro
df_dados_consolidado[df_dados_consolidado["Cargo"].isin(cargos_relevantes)].sort_values(by="Despesa_media",ascending=False)
# Out:
#                                         Cargo  Despesa_media  \
# 686                  TECNICO DO SEGURO SOCIAL        4302.48
# 494                             Não informado        3260.26
# 443         Informações protegidas por sigilo        3137.48
# 72                         ANALISTA AMBIENTAL        2596.94
# 209  AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL        2418.11
# 569          PROFESSOR DO MAGISTERIO SUPERIOR        2032.08
# 113    ANALISTA TRIBUTARIO REC FEDERAL BRASIL        1746.79
# 208       AUDITOR FISCAL FEDERAL AGROPECUARIO        1465.85
# 776   TECNICO INFOR GEOGRAFICAS E ESTATISTICA        1457.08
# 570     PROFESSOR ENS BASICO TECN TECNOLOGICO        1402.20
# 179               ASSISTENTE EM ADMINISTRAçãO        1291.03
# 315               CONTRATADO LEI 8745/93 - NI         984.45
#
#      Dias_de_viagem_medio  Despesas_soma           Destinos_mais_frequentes  \
# 686                 11.37    45881679.92                        Brasília/DF
# 494                  8.01  1049266194.86                        Brasília/DF
# 443                  7.41   370919369.30  Informações protegidas por sigilo
# 72                   5.13    35344371.79                        Brasília/DF
# 209                  2.84    24405946.47                        Brasília/DF
# 569                  3.87   110890764.22                        Brasília/DF
# 113                  3.06    14868670.22                   Foz do Iguaçu/PR
# 208                  2.06    24306782.30                        Brasília/DF
# 776                  3.19    15816641.46                        Brasília/DF
# 570                  2.34    52548741.25                        Brasília/DF
# 179                  2.17    15094703.63                        Brasília/DF
# 315                  2.84    17510463.07                           Bauru/SP
#
#      Numero_de_viagens
# 686              10664
# 494             321835
# 443             118222
# 72               13610
# 209              10093
# 569              54570
# 113               8512
# 208              16582
# 776              10855
# 570              37476
# 179              11692
# 315              17787

# %%
df_final
# Out:
#                                         Cargo  Despesa_media  \
# 494                             Não informado        3260.26
# 443         Informações protegidas por sigilo        3137.48
# 569          PROFESSOR DO MAGISTERIO SUPERIOR        2032.08
# 570     PROFESSOR ENS BASICO TECN TECNOLOGICO        1402.20
# 315               CONTRATADO LEI 8745/93 - NI         984.45
# 208       AUDITOR FISCAL FEDERAL AGROPECUARIO        1465.85
# 72                         ANALISTA AMBIENTAL        2596.94
# 179               ASSISTENTE EM ADMINISTRAçãO        1291.03
# 776   TECNICO INFOR GEOGRAFICAS E ESTATISTICA        1457.08
# 686                  TECNICO DO SEGURO SOCIAL        4302.48
# 209  AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL        2418.11
# 113    ANALISTA TRIBUTARIO REC FEDERAL BRASIL        1746.79
#
#      Dias_de_viagem_medio  Despesas_soma           Destinos_mais_frequentes  \
# 494                  8.01  1049266194.86                        Brasília/DF
# 443                  7.41   370919369.30  Informações protegidas por sigilo
# 569                  3.87   110890764.22                        Brasília/DF
# 570                  2.34    52548741.25                        Brasília/DF
# 315                  2.84    17510463.07                           Bauru/SP
# 208                  2.06    24306782.30                        Brasília/DF
# 72                   5.13    35344371.79                        Brasília/DF
# 179                  2.17    15094703.63                        Brasília/DF
# 776                  3.19    15816641.46                        Brasília/DF
# 686                 11.37    45881679.92                        Brasília/DF
# 209                  2.84    24405946.47                        Brasília/DF
# 113                  3.06    14868670.22                   Foz do Iguaçu/PR
#
#      Numero_de_viagens
# 494             321835
# 443             118222
# 569              54570
# 570              37476
# 315              17787
# 208              16582
# 72               13610
# 179              11692
# 776              10855
# 686              10664
# 209              10093
# 113               8512

# %%
df_final = df_final.sort_values(by="Numero_de_viagens",ascending=False)

# %%
df_final.plot(x="Cargo", y="Numero_de_viagens", kind="bar")
# Out:
# <Axes: xlabel='Cargo'>

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(16, 6))

ax.barh(df_final["Cargo"], df_final["Numero_de_viagens"], color = "#3ee679")
ax.invert_yaxis()
ax.set_facecolor("#1c273b")

fig.suptitle("Viagens por cargo público (2023)")

plt.figtext(0.89, 0.90, "Fonte: Portal da Transparência", fontsize=10, ha="right")
plt.grid(color = "gray", linestyle = "--", linewidth = "0.2")
plt.yticks(fontsize = 8)
plt.xlabel("Número de viagens")
plt.show()
